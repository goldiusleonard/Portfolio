# %% [markdown]
# ## Start Recording Tiktok Live Content

# %%
import subprocess

def get_video_metadata(file_path):
    """
    Retrieve the metadata (comment) from the video file.
    """
    try:
        command = [
            'ffprobe',
            '-v', 'error',
            '-select_streams', 'v:0',
            '-show_entries', 'format_tags=comment',
            '-of', 'default=noprint_wrappers=1:nokey=1',
            file_path
        ]
        
        result = subprocess.check_output(command, stderr=subprocess.STDOUT)
        metadata = result.decode('utf-8').strip()
        
        return metadata
    except subprocess.CalledProcessError as e:
        print(f"Error retrieving metadata: {e.output.decode()}")
        return None

# %%
import os
import requests

username = "dnsykla"
user_id = "001"
save_interval = 10
download_dir = f'recordings/client_videos/{user_id}'

if not os.path.exists(download_dir):
    os.makedirs(download_dir)

url = f"http://localhost:8000/tiktok/live/video/start-recording"

params = {
    "username": username,
    "user_id": user_id,
    "save_interval": save_interval
}

response = requests.post(url, params=params, stream=True, verify=False)

chunk_size = 1024 * 1024 * 1024 

if response.status_code == 200:
    print(f"Streaming started successfully for {username}!")

    chunk_count = 1
    for chunk in response.iter_content(chunk_size=chunk_size):
        if chunk :
            chunk_filename = os.path.join(download_dir, f"{username}_vid{chunk_count}.mp4")
            with open(chunk_filename, "wb") as f:
                f.write(chunk)
            print(f"Video {chunk_count} saved as {chunk_filename}")
            chunk_count += 1

    comment_text = get_video_metadata(os.path.join(download_dir, f"{username}_vid{chunk_count-1}.mp4"))
    if comment_text:
        print(f"Retrieved comment text: {comment_text}")
    else:
        print("No comment text found.")

else:
    print(f"Failed to start streaming for {username}: {response.status_code}")
    print(response.text)
# Out:
# Streaming started successfully for kerminlovedcarr!
# Video 1 saved as recordings/client_videos/001/kerminlovedcarr_vid1.mp4
# Video 2 saved as recordings/client_videos/001/kerminlovedcarr_vid2.mp4
# Video 3 saved as recordings/client_videos/001/kerminlovedcarr_vid3.mp4
# Video 4 saved as recordings/client_videos/001/kerminlovedcarr_vid4.mp4
# Video 5 saved as recordings/client_videos/001/kerminlovedcarr_vid5.mp4
# Video 6 saved as recordings/client_videos/001/kerminlovedcarr_vid6.mp4
# Video 7 saved as recordings/client_videos/001/kerminlovedcarr_vid7.mp4
# Retrieved comment text: {'full_video_url': 'https://ada-radar.s3.amazonaws.com/live-tiktok-recordings/recordings/server_videos/001/kerminlovedcarr_full_video.mp4?AWSAccessKeyId=AKIAXAJLZ544IJYP62N5&Signature=sqckIh4YB6VC%2BMa5yCdx9%2Fxlq1A%3D&Expires=1737604754', 'user_id': '001', 'username': 'kerminlovedcarr', 'start_time': '2025-01-23T10:57:55.665366', 'end_time': '2025-01-23T10:59:14.536155'}

# %% [markdown]
# ## Stop Recording Tiktok Live Content

# %%
import os
import requests

username = "capiqass"
user_id = "hazim.z@userdata.tech"
url = f"http://18.143.205.116:8000/tiktok/live/video/stop-recording"

params = {
    "username": username,
    "user_id": user_id
}

response = requests.post(url, params=params, verify=False)

if response.status_code == 200:
    data = response.json()
    print(f"Recording stopped successfully for {username}!")
    print(data.get("message", "No message provided"))
    
    if "start_time" in data and "end_time" in data:
        print(f"Start Time: {data['start_time']}")
        print(f"End Time: {data['end_time']}")

else:
    print(response.json().get("detail", "No error message provided"))
# Out:
# Recording stopped successfully for en0lal0ne!
# No active recording session for tiktok username 'en0lal0ne' from 'hazim.z@userdata.tech' user ID.

# %% [markdown]
# ## Start Recording Tiktok Live Comments

# %%
import requests

username = "user21206660"
user_id = "001" 

url = f"http://ad538543902314c978de89ddb732a52a-131135640.ap-southeast-1.elb.amazonaws.com:8000/tiktok/live/comments/start-streaming"

params = {
    "username": username,
    "user_id": user_id
}

response = requests.post(url, params=params, stream=True, verify=False)

if response.status_code == 200:
    print(f"Stream started successfully for {username}!\n")
    try:
        for line in response.iter_lines():
            if line:
                print(line.decode("utf-8")) 
    except:
        print("\nStream interrupted and stopped.")
else:
    print(f"Failed to start stream for {username}. Status code: {response.status_code}")
    print(response.text)
# Out:
# Stream started successfully for user21206660!
#
# data: {"id": 7470443622611421960, "text": "saya plak? kenal tak", "user": {"id": 7136237491472745499, "sec_uid": "MS4wLjABAAAAvylSgANTvmb7UywzxWs0b4dxHZVYsm_0bplsFu-6bZB8JESf6cwRiQR3J35JcVsE", "unique_id": "cadlisme", "nickname": "AcadKitHeart", "signature": "", "avatar": "https://p16-sign-sg.tiktokcdn.com/aweme/100x100/tos-alisg-avt-0068/477504ecbfba0bc0dba9ab9f3e395d75.webp?lk3s=a5d48078&nonce=73787&refresh_token=2edf7b00002ec9c159804c1d8badb8ae&x-expires=1739520000&x-signature=W%2F3mvZyYx%2FjbOOwnjr%2Ft8G8dwf4%3D&shp=a5d48078&shcp=fdd36af4", "verified": false, "secret": 0, "aweme_count": 0, "following_count": 159, "follower_count": 83, "total_favorited": 0, "ins_id": "", "youtube_channel_title": "", "youtube_channel_id": "", "twitter_name": "", "twitter_id": ""}, "create_time": 1739348203071, "digg_count": 0, "reply_total": 0, "status": 1, "updated_at": "2025-02-12 08:16:43", "created_at": "2025-02-12 08:16:43", "is_flagged": false, "request_id": null}
# data: {"id": 7470443620975577863, "text": "tanya mia \ud83d\uddff", "user": {"id": 7092637794409792513, "sec_uid": "MS4wLjABAAAAo5ajAvJ-NeCglZyo9GTgWXUqAQI3WX52GCWfLIYYukUdcG0ShhSJ4DZ7vxTdPshK", "unique_id": "nasr4u_", "nickname": "HAJIRCING", "signature": "", "avatar": "https://p16-sign-sg.tiktokcdn.com/tos-alisg-avt-0068/ff39ea13483191d84bcf5b0685e1cf5d~tplv-tiktokx-cropcenter:100:100.jpeg?dr=14579&nonce=81976&refresh_token=924f504ee5383a7316b56603f65edd07&x-expires=1739520000&x-signature=2qRHkOaaLiQA93aPqnM9e%2FMufew%3D&idc=my2&ps=13740610&shcp=fdd36af4&shp=a5d48078&t=4d5b0474", "verified": false, "secret": 0, "aweme_count": 0, "following_count": 143, "follower_count": 120, "total_favorited": 0, "ins_id": "", "youtube_channel_title": "", "youtube_channel_id": "", "twitter_name": "", "twitter_id": ""}, "create_time": 1739348206777, "digg_count": 0, "reply_total": 0, "status": 1, "updated_at": "2025-02-12 08:16:46", "created_at": "2025-02-12 08:16:46", "is_flagged": false, "request_id": null}
# data: {"id": 7470443659336878869, "text": "cantikkkk nyo aok", "user": {"id": 7464071361603437589, "sec_uid": "MS4wLjABAAAAjQ9D_IJfwM1ir93ExXe6tLj1p7A3NCZAZlwZPYUE8n4Ts3EH0SnSBGTCQL3vzIc3", "unique_id": "userlissya01", "nickname": "lisya", "signature": "", "avatar": "https://p16-sign-sg.tiktokcdn.com/tos-alisg-avt-0068/9f18a6f05bd1566d77f9852fe9f29978~tplv-tiktokx-cropcenter:100:100.jpeg?dr=14579&nonce=99343&refresh_token=9b873477e53f56d331ef4ca95818a946&x-expires=1739520000&x-signature=VMbwz6SOC8kPERlUgRShrTXoMlQ%3D&idc=my2&ps=13740610&shcp=fdd36af4&shp=a5d48078&t=4d5b0474", "verified": false, "secret": 0, "aweme_count": 0, "following_count": 28, "follower_count": 33, "total_favorited": 0, "ins_id": "", "youtube_channel_title": "", "youtube_channel_id": "", "twitter_name": "", "twitter_id": ""}, "create_time": 1739348216955, "digg_count": 0, "reply_total": 0, "status": 1, "updated_at": "2025-02-12 08:16:56", "created_at": "2025-02-12 08:16:56", "is_flagged": false, "request_id": null}
# data: {"id": 7470443690944793364, "text": "tu mesin Pepsi", "user": {"id": 7092637794409792513, "sec_uid": "MS4wLjABAAAAo5ajAvJ-NeCglZyo9GTgWXUqAQI3WX52GCWfLIYYukUdcG0ShhSJ4DZ7vxTdPshK", "unique_id": "nasr4u_", "nickname": "HAJIRCING", "signature": "", "avatar": "https://p16-sign-sg.tiktokcdn.com/tos-alisg-avt-0068/ff39ea13483191d84bcf5b0685e1cf5d~tplv-tiktokx-cropcenter:100:100.jpeg?dr=14579&nonce=81574&refresh_token=811eea2e85ea7a0756ed7ae15838fc31&x-expires=1739520000&x-signature=2qRHkOaaLiQA93aPqnM9e%2FMufew%3D&idc=my2&ps=13740610&shcp=fdd36af4&shp=a5d48078&t=4d5b0474", "verified": false, "secret": 0, "aweme_count": 0, "following_count": 143, "follower_count": 120, "total_favorited": 0, "ins_id": "", "youtube_channel_title": "", "youtube_channel_id": "", "twitter_name": "", "twitter_id": ""}, "create_time": 1739348223664, "digg_count": 0, "reply_total": 0, "status": 1, "updated_at": "2025-02-12 08:17:03", "created_at": "2025-02-12 08:17:03", "is_flagged": false, "request_id": null}
# data: {"id": 7470443747639479061, "text": "akim tnye mne ain", "user": {"id": 6791343101362471937, "sec_uid": "MS4wLjABAAAAsaKrvkM0Fa04fEMrjsi9v3E9Swf2ZJawAoC2wabZBvDoTgBRuYc96hOFmIeKPnqB", "unique_id": "iqramsemmm._", "nickname": "hairi \u22c6", "signature": "", "avatar": "https://p16-sign-sg.tiktokcdn.com/tos-alisg-avt-0068/b715767a10c907b351716724269145c1~tplv-tiktokx-cropcenter:100:100.jpeg?dr=14579&nonce=75552&refresh_token=d01eb77e82176d4e11eda9dcf458b235&x-expires=1739520000&x-signature=ZOVJDJ6zJwa2PR%2FXWqG6jJddz7Y%3D&idc=my2&ps=13740610&shcp=fdd36af4&shp=a5d48078&t=4d5b0474", "verified": false, "secret": 0, "aweme_count": 0, "following_count": 50, "follower_count": 370, "total_favorited": 0, "ins_id": "", "youtube_channel_title": "", "youtube_channel_id": "", "twitter_name": "", "twitter_id": ""}, "create_time": 1739348237719, "digg_count": 0, "reply_total": 0, "status": 1, "updated_at": "2025-02-12 08:17:17", "created_at": "2025-02-12 08:17:17", "is_flagged": false, "request_id": null}
# data: {"id": 7470443803594378004, "text": "@\u6cd5\u54c8\u5a1c\ud83c\udfc4\ud83c\udffb\u200d\u2640\ufe0f bagus latuuu", "user": {"id": 7092637794409792513, "sec_uid": "MS4wLjABAAAAo5ajAvJ-NeCglZyo9GTgWXUqAQI3WX52GCWfLIYYukUdcG0ShhSJ4DZ7vxTdPshK", "unique_id": "nasr4u_", "nickname": "HAJIRCING", "signature": "", "avatar": "https://p16-sign-sg.tiktokcdn.com/tos-alisg-avt-0068/ff39ea13483191d84bcf5b0685e1cf5d~tplv-tiktokx-cropcenter:100:100.jpeg?dr=14579&nonce=89485&refresh_token=53ce590612bfb1a27e5d142c488d2bac&x-expires=1739520000&x-signature=2qRHkOaaLiQA93aPqnM9e%2FMufew%3D&idc=my2&ps=13740610&shcp=fdd36af4&shp=a5d48078&t=4d5b0474", "verified": false, "secret": 0, "aweme_count": 0, "following_count": 143, "follower_count": 120, "total_favorited": 0, "ins_id": "", "youtube_channel_title": "", "youtube_channel_id": "", "twitter_name": "", "twitter_id": ""}, "create_time": 1739348249600, "digg_count": 0, "reply_total": 0, "status": 1, "updated_at": "2025-02-12 08:17:29", "created_at": "2025-02-12 08:17:29", "is_flagged": false, "request_id": null}
# data: {"message": "TikTok comment recording for user user21206660 has stopped."}
# data: {"message": "Stream comments stopped successfully", "user_id": "001", "username": "user21206660", "start_time": "2025-02-12T08:17:45.133680", "end_time": "2025-02-12T08:18:26.569224"}

# %% [markdown]
# ## Stop Recording Tiktok Live Comments

# %%
import os
import requests

username = "capiqass"
user_id = "goldius.leo@userdata.tech"
url = f"http://ad538543902314c978de89ddb732a52a-131135640.ap-southeast-1.elb.amazonaws.com:8000/tiktok/live/comments/stop-streaming"

params = {
    "username": username,
    "user_id": user_id
}

response = requests.post(url, params=params, verify=False)

if response.status_code == 200:
    data = response.json()
    print(f"Recording stopped successfully for {username}!")
    print(data.get("message", "No message provided"))
else:
    print(response.json().get("detail", "No error message provided"))
# Out:
# Recording stopped successfully for hijriguzelresourcesgqa!
# Stream comments stopped successfully for user 'hijriguzelresourcesgqa' with user ID 'goldius.leo@userdata.tech'.

# %% [markdown]
# ## Check Live Status

# %%
import requests

username = "capiqass"
url = "http://18.143.205.116:8000/tiktok/live/user/status"

params = {"username": username}

response = requests.post(url, params=params, stream=True, verify=False)

if response.status_code == 200:
    data = response.json()
    check_alive = data['data']
    print(check_alive)
    if check_alive['alive']:
        print(f"User {check_alive['username']} is live. Room ID: {check_alive['room_id']}")
    else:
        print(f"User {check_alive['username']} is not live.")
else:
    print(f"Failed to check live status for {username}. Status code: {response.status_code}")
    print(response.text)
# Out:
# {'alive': False, 'username': 'nikpruofficial', 'room_id': '7457817521169763092'}
# User nikpruofficial is not live.

# %% [markdown]
# ## Live Stream Display

# %%
import requests
import os

username = "capiqass"
download_dir = f'recordings/server_videos/{username}'

if not os.path.exists(download_dir):
    os.makedirs(download_dir)

url = f"http://18.143.205.116:8000/tiktok/live/video/stream-display"

params = {
    "username": username
}

response = requests.get(url, params=params, stream=True, verify=False)

if response.status_code == 200:
    print("Streaming started...")
    
    with open(os.path.join(download_dir, f"{username}_livestream.flv"), "wb") as f:
        for chunk in response.iter_content(chunk_size=4096):
            if chunk:
                f.write(chunk)
else:
    print(f"Failed to display live stream for {username}. Status code: {response.status_code}")
    print(response.text)
# Out:
# Streaming started...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# Writing chunk...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 22
#      19 print("Streaming started...")
#      21 with open(os.path.join(download_dir, f"{username}_livestream.flv"), "wb") as f:
# ---> 22     for chunk in response.iter_content(chunk_size=4096):
#      23         if chunk:
#      24             f.write(chunk)
#
# File ~/Documents/anaconda3/envs/crawler/lib/python3.11/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/Documents/anaconda3/envs/crawler/lib/python3.11/site-packages/urllib3/response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1041 """
#    1042 A generator wrapper for the read() method. A call will block until
#    1043 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1054     'content-encoding' header.
#    1055 """
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/Documents/anaconda3/envs/crawler/lib/python3.11/site-packages/urllib3/response.py:1206, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1203     amt = None
#    1205 while True:
# -> 1206     self._update_chunk_length()
#    1207     if self.chunk_left == 0:
#    1208         break
#
# File ~/Documents/anaconda3/envs/crawler/lib/python3.11/site-packages/urllib3/response.py:1125, in HTTPResponse._update_chunk_length(self)
#    1123 if self.chunk_left is not None:
#    1124     return None
# -> 1125 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1126 line = line.split(b";", 1)[0]
#    1127 try:
#
# File ~/Documents/anaconda3/envs/crawler/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## Remove All Active Sessions

# %%
import requests

url = "http://18.143.205.116:8000/tiktok/live/video/remove-all-sessions"

response = requests.post(url)

if response.status_code == 200:
    data = response.json()
    print(data.get("message", "No message provided"))
else:
    print(f"Failed to remove active sessions. Status code: {response.status_code}")
    print(response.text)
# Out:
# All active video sessions have been removed successfully.

# %% [markdown]
# ## Instagram Posts and Comments Crawler

# %%
import requests
import json

username = "khalies.klp48"
searchLimit = 1
start_date = "2025-01-01T14:30:00Z"
url = "http://localhost:8000/instagram/posts"

params = {"username": username, "searchLimit": searchLimit, "start_date": start_date}

try:
    response = requests.get(url, params=params, verify=False)

    if response.status_code == 200:
        data = response.json()
        print("Response:", data)

        # Save data to a JSON file
        file_name = f"{username}_apify_posts.json"
        with open(file_name, "w", encoding="utf-8") as json_file:
            json.dump(data, json_file, indent=4, ensure_ascii=False)

        print(f"Response saved to {file_name}")

    else:
        print(f"Error: {response.status_code}, Message: {response.text}")

except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")
# Out:
# Response: {'posts': [{'id': '3559055713164891743', 'shortCode': 'DFkTlB_BJZf', 'caption': 'Its so fun!🇹🇭✨', 'commentsCount': 30, 'dimensionsHeight': 1349, 'dimensionsWidth': 1080, 'displayUrl': 'https://instagram.fmnl17-7.fna.fbcdn.net/v/t51.2885-15/476050852_17875896807253556_1490012958248595519_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08_tt6&_nc_ht=instagram.fmnl17-7.fna.fbcdn.net&_nc_cat=108&_nc_oc=Q6cZ2AGUPBD_Nh-1J8EQ7lxCJnfpV9aTxYO3DTK6jAOpyPnXjWw3KlYYZDp7XmHM5XjrFuU&_nc_ohc=lywDyJ9topYQ7kNvgH2rl97&_nc_gid=5c0fdd8ce814411cad615015a19d7720&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYC1QMCcdWriF9-a9gloq81Ys1ApX9WV7u6q9Cepu-TiSQ&oe=67B8E6D5&_nc_sid=10d13b', 'likesCount': 2419, 'timestamp': '2025-02-02T10:35:24.000Z', 'owner': {'id': '67614277555', 'username': 'khalies.klp48', 'full_name': 'Khalies♡'}, 'usertags': '', 'child_posts': [{'id': '3559055699281727926', 'displayUrl': 'https://instagram.fmnl17-7.fna.fbcdn.net/v/t51.2885-15/476050852_17875896807253556_1490012958248595519_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08_tt6&_nc_ht=instagram.fmnl17-7.fna.fbcdn.net&_nc_cat=108&_nc_oc=Q6cZ2AGUPBD_Nh-1J8EQ7lxCJnfpV9aTxYO3DTK6jAOpyPnXjWw3KlYYZDp7XmHM5XjrFuU&_nc_ohc=lywDyJ9topYQ7kNvgH2rl97&_nc_gid=5c0fdd8ce814411cad615015a19d7720&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYC1QMCcdWriF9-a9gloq81Ys1ApX9WV7u6q9Cepu-TiSQ&oe=67B8E6D5&_nc_sid=10d13b'}, {'id': '3559055699072111141', 'displayUrl': 'https://instagram.fmnl17-7.fna.fbcdn.net/v/t51.2885-15/476247877_17875896816253556_4246110607330582379_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08_tt6&_nc_ht=instagram.fmnl17-7.fna.fbcdn.net&_nc_cat=108&_nc_oc=Q6cZ2AGUPBD_Nh-1J8EQ7lxCJnfpV9aTxYO3DTK6jAOpyPnXjWw3KlYYZDp7XmHM5XjrFuU&_nc_ohc=qaiWoy4ZFsMQ7kNvgEYE2WV&_nc_gid=5c0fdd8ce814411cad615015a19d7720&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYD8xULRkAg5ubV64hARfxq48YNPVyCq6_qQOsvBqy4mNw&oe=67B8D6A9&_nc_sid=10d13b'}, {'id': '3559055699281792664', 'displayUrl': 'https://instagram.fmnl17-7.fna.fbcdn.net/v/t51.2885-15/475969672_17875896825253556_3651235963177328883_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08_tt6&_nc_ht=instagram.fmnl17-7.fna.fbcdn.net&_nc_cat=108&_nc_oc=Q6cZ2AGUPBD_Nh-1J8EQ7lxCJnfpV9aTxYO3DTK6jAOpyPnXjWw3KlYYZDp7XmHM5XjrFuU&_nc_ohc=0Sox3s92c4cQ7kNvgEl2uUs&_nc_gid=5c0fdd8ce814411cad615015a19d7720&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYDeugDOeFurXQzUehyxKxgfyMFpoNIcpifKUlBjgQ1rTA&oe=67B8CA1B&_nc_sid=10d13b'}, {'id': '3559055699323747602', 'displayUrl': 'https://instagram.fmnl17-7.fna.fbcdn.net/v/t51.2885-15/476181381_17875896843253556_8296066526795332366_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08_tt6&_nc_ht=instagram.fmnl17-7.fna.fbcdn.net&_nc_cat=108&_nc_oc=Q6cZ2AGUPBD_Nh-1J8EQ7lxCJnfpV9aTxYO3DTK6jAOpyPnXjWw3KlYYZDp7XmHM5XjrFuU&_nc_ohc=CHAO78Nt92UQ7kNvgHnE7NY&_nc_gid=5c0fdd8ce814411cad615015a19d7720&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYDKEHxd4f46F86BZUsfIrzWYYeP3v0maB58lPIm9mGs-A&oe=67B8E181&_nc_sid=10d13b'}, {'id': '3559055699474689545', 'displayUrl': 'https://instagram.fmnl17-7.fna.fbcdn.net/v/t51.2885-15/475995908_17875896855253556_117204266055676655_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08_tt6&_nc_ht=instagram.fmnl17-7.fna.fbcdn.net&_nc_cat=108&_nc_oc=Q6cZ2AGUPBD_Nh-1J8EQ7lxCJnfpV9aTxYO3DTK6jAOpyPnXjWw3KlYYZDp7XmHM5XjrFuU&_nc_ohc=ap7ql2TPirkQ7kNvgGJ3Na2&_nc_gid=5c0fdd8ce814411cad615015a19d7720&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYCmKecDLWYcHcxC8NybtoY3UEEmagXQf-8cZPZ4C1TDQQ&oe=67B8D8BD&_nc_sid=10d13b'}]}], 'comments': [[{'id': '17880558171232729', 'created_at': '2025-02-07T09:16:39.000Z', 'text': 'Nyasar rek', 'owner': {'id': '27247138609', 'is_verified': False, 'profile_pic_url': 'https://instagram.fmnl17-2.fna.fbcdn.net/v/t51.2885-19/473584927_626444703228679_8319437186724384352_n.jpg?stp=dst-jpg_s150x150_tt6&_nc_ht=instagram.fmnl17-2.fna.fbcdn.net&_nc_cat=107&_nc_oc=Q6cZ2AGUPBD_Nh-1J8EQ7lxCJnfpV9aTxYO3DTK6jAOpyPnXjWw3KlYYZDp7XmHM5XjrFuU&_nc_ohc=qRzyp3H0AfQQ7kNvgFugYfp&_nc_gid=5c0fdd8ce814411cad615015a19d7720&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYCZXDPo2y3SkD5e0sq_vbtKHIwVyNqaUDI5KKmz30t37g&oe=67B8C2C7&_nc_sid=10d13b', 'username': 'gabrieldo_s ...
# Response saved to khalies.klp48_apify_posts.json

# %% [markdown]
# ## Instagram Profile Crawler

# %%
import requests
import json

username = "khalies.klp48"
url = "http://localhost:8000/instagram/profile"

params = {"username": username}

try:
    response = requests.get(url, params=params, verify=False)

    if response.status_code == 200:
        data = response.json()
        print("Response:", data)

        # Save data to a JSON file
        file_name = f"{username}_apify_profile.json"
        with open(file_name, "w", encoding="utf-8") as json_file:
            json.dump(data, json_file, indent=4, ensure_ascii=False)

        print(f"Response saved to {file_name}")

    else:
        print(f"Error: {response.status_code}, Message: {response.text}")

except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")
# Out:
# Response: {'profile': {'id': '67614277555', 'username': 'khalies.klp48', 'fullName': 'Khalies♡', 'biography': 'KLP48 1st generation member♡\nThe world is lucky to have you and me ;)', 'followersCount': 10655, 'followsCount': 48, 'hasChannel': False, 'highlightReelCount': 3, 'isBusinessAccount': False, 'joinedRecently': False, 'businessCategoryName': 'Artist', 'private': False, 'verified': False, 'profilePicUrl': 'https://scontent-atl3-1.cdninstagram.com/v/t51.2885-19/453007374_368047542984334_3323652620662337368_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_ht=scontent-atl3-1.cdninstagram.com&_nc_cat=110&_nc_oc=Q6cZ2AEKdUQ373be9a7TvSoCS7fxIdWUFHkPaDkI12H0HcrmCuCLzGfFrbwtCOtX2d0HW0Y&_nc_ohc=I77XssXZn5gQ7kNvgEdzl8R&_nc_gid=e77579cd62344f7482365992cb39359e&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AYDiRRZDTSLCl7uEsMUv7oHNF2mIg4acfRXnoGt8BomXUQ&oe=67B8D73E&_nc_sid=8b3546', 'profilePicUrlHD': 'https://scontent-atl3-1.cdninstagram.com/v/t51.2885-19/453007374_368047542984334_3323652620662337368_n.jpg?stp=dst-jpg_s320x320_tt6&_nc_ht=scontent-atl3-1.cdninstagram.com&_nc_cat=110&_nc_oc=Q6cZ2AEKdUQ373be9a7TvSoCS7fxIdWUFHkPaDkI12H0HcrmCuCLzGfFrbwtCOtX2d0HW0Y&_nc_ohc=I77XssXZn5gQ7kNvgEdzl8R&_nc_gid=e77579cd62344f7482365992cb39359e&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AYCoeOypjzBQmYOzj0h3jvZE4f_42KjtOpbbYfKIuvILjw&oe=67B8D73E&_nc_sid=8b3546'}}
# Response saved to khalies.klp48_profile.json

# %% [markdown]
# ## Instagram Trending Hashtags Crawler

# %%
import requests
import json

maxHashtags = 2
url = "http://localhost:8000/instagram/trending/hashtags"

params = {"maxHashtags": maxHashtags}

try:
    response = requests.get(url, params=params, verify=False)

    if response.status_code == 200:
        data = response.json()
        print("Response:", data)

        # Save data to a JSON file
        file_name = f"apify_trending_hashtags.json"
        with open(file_name, "w", encoding="utf-8") as json_file:
            json.dump(data, json_file, indent=4, ensure_ascii=False)

        print(f"Response saved to {file_name}")

    else:
        print(f"Error: {response.status_code}, Message: {response.text}")

except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")
# Out:
# Response: {'hashtags': [{'title': '📸 #MalaysiaMerdeka', 'region': 'MY', 'timestamp': '2025-02-17T09:37:56.745867', 'details': {'engagement_stats': {'likes': '250k', 'comments': '50k', 'shares': '10k'}, 'trending_reason': 'National Independence Day celebrations', 'user_demographics': 'Malaysian citizens, patriotic individuals, all ages', 'social_impact': 'Fostering national pride, remembrance of history, and unity'}}, {'title': '📸 #CutiCutiMalaysia', 'region': 'MY', 'timestamp': '2025-02-17T09:37:56.745901', 'details': {'engagement_stats': {'likes': '150k', 'comments': '30k', 'shares': '5k'}, 'trending_reason': 'Domestic tourism promotion campaign', 'user_demographics': 'Travel-minded Malaysians, families, young adults', 'social_impact': 'Encouraging local tourism, supporting domestic businesses, and promoting a sense of wanderlust'}}]}
# Response saved to apify_trending_hashtags.json

# %% [markdown]
# ## Instagram Trending Posts Search by Hashtag Crawler

# %%
import requests
import json

# 28 number of posts will be extracted

hashtag = "fun"
date = "2025-01-31T14:30:00Z"
url = "http://localhost:8000/instagram/trending/posts/search/by-hashtag"

params = {"hashtag": hashtag, "start_date": date}

try:
    response = requests.get(url, params=params, verify=False)

    if response.status_code == 200:
        data = response.json()
        print("Response:", data)

        # Save data to a JSON file
        file_name = f"apify_trending_posts_byhashtag.json"
        with open(file_name, "w", encoding="utf-8") as json_file:
            json.dump(data, json_file, indent=4, ensure_ascii=False)

        print(f"Response saved to {file_name}")

    else:
        print(f"Error: {response.status_code}, Message: {response.text}")

except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")
# Out:
# Response: {'posts': [{'id': '3569870316307802891', 'shortCode': 'DGKuiOBvOsL', 'caption': 'or kuch ?\n•\n•\n•\nFollow For More : @noblestalwarts \n•\n•\n•\n#meme #memes #funny #memesdaily #dankmemes #funnymemes #lol #humor #memepage #dank #love #follow #like #comedy #instagram #dankmeme #anime #dailymemes #memestagram #tiktok #viral #lmao #shitpost #edgymemes #funnymeme #fun #offensivememes #explorepage #instagood #explore', 'commentsCount': 4, 'dimensionsHeight': 1136, 'dimensionsWidth': 640, 'displayUrl': 'https://instagram.fcpq5-1.fna.fbcdn.net/v/t51.2885-15/480410562_653589747115197_7161123607015899075_n.jpg?stp=dst-jpg_e15_tt6&_nc_ht=instagram.fcpq5-1.fna.fbcdn.net&_nc_cat=109&_nc_oc=Q6cZ2AFMjIQxDF8Xq8CwJNdptN7DldFa1bZMWb0RTEOajyl7uvP8cF04N2XwRiA7ZTF6jyQ&_nc_ohc=7I1FXUQdxeMQ7kNvgFnLdsA&_nc_gid=53abdf0865ee40d3aecfeeb4045e13e1&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYD_PDtY6_P5UKT2fPoXKHV4Ec_umvVJnCVF4ZaA7iSIJw&oe=67B8F65A&_nc_sid=10d13b', 'likesCount': 305, 'timestamp': '2025-02-17T08:42:59.000Z', 'owner': {'id': '60169647456', 'username': 'noblestalwarts', 'full_name': 'NobleStalWarts ٹھاکر'}, 'usertags': '', 'child_posts': []}, {'id': '3569349458937460468', 'shortCode': 'DGI4GvzMzb0', 'caption': 'കൂടുതൽ tips follow me, @vinz_rac @reshmi__resmi \n.\n.\n.\n.\n.\n.\n#funny #bahrain #comedy #manama #trendingreels #pravasimalayali #buali #tips #fun #food #tubli #zinj #pravasi #kerala #love', 'commentsCount': 28, 'dimensionsHeight': 1137, 'dimensionsWidth': 640, 'displayUrl': 'https://scontent-cdg4-3.cdninstagram.com/v/t51.2885-15/479860924_18075285214661086_6854451795168446236_n.jpg?stp=dst-jpg_e15_tt6&_nc_ht=scontent-cdg4-3.cdninstagram.com&_nc_cat=110&_nc_oc=Q6cZ2AG-pJ9St-XZOZTLGJZAR9JsxokFlfPdSFJI3NzhO0nkwBz23IJDea-HsGmUbkkQ7ZM&_nc_ohc=M9J7fgPiUW0Q7kNvgE38vOs&_nc_gid=b03907e7804148aea4ed56769004bcde&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYDFY_F_t1SJhjZWnGCBZ1f7Ff5gM1DALK-bo1ieyJ1jZg&oe=67B8DCA2&_nc_sid=10d13b', 'likesCount': 597, 'timestamp': '2025-02-16T15:30:40.000Z', 'owner': {'id': '19874997085', 'username': 'i_am_soumya_vinz', 'full_name': 'Soumya Raveendran'}, 'usertags': [{'full_name': 'Bu Ali Spice Restaurant', 'id': '7903998206', 'is_verified': False, 'profile_pic_url': 'https://scontent-cdg4-2.cdninstagram.com/v/t51.2885-19/469004851_922408333287696_1025230258989319143_n.jpg?stp=dst-jpg_s150x150_tt6&_nc_ht=scontent-cdg4-2.cdninstagram.com&_nc_cat=100&_nc_oc=Q6cZ2AG-pJ9St-XZOZTLGJZAR9JsxokFlfPdSFJI3NzhO0nkwBz23IJDea-HsGmUbkkQ7ZM&_nc_ohc=jsveyLNWL00Q7kNvgEJBlr2&_nc_gid=b03907e7804148aea4ed56769004bcde&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYDqOyGA37UlrsLExsHFN3HRQTT5NB3S3AyL7p3Vzm7tFQ&oe=67B8CB09&_nc_sid=10d13b', 'username': 'buali_restaurant.bh'}, {'full_name': 'Reshmi', 'id': '46522097343', 'is_verified': False, 'profile_pic_url': 'https://scontent-cdg4-1.cdninstagram.com/v/t51.2885-19/469715616_541582232032876_6642300539381286086_n.jpg?stp=dst-jpg_s150x150_tt6&_nc_ht=scontent-cdg4-1.cdninstagram.com&_nc_cat=104&_nc_oc=Q6cZ2AG-pJ9St-XZOZTLGJZAR9JsxokFlfPdSFJI3NzhO0nkwBz23IJDea-HsGmUbkkQ7ZM&_nc_ohc=xS8EU_ijlLIQ7kNvgEbRlRB&_nc_gid=b03907e7804148aea4ed56769004bcde&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYB46LhVxqawMySKirIPqEb8d7tveoJsa0Cjzvr1ZQky3A&oe=67B8C90C&_nc_sid=10d13b', 'username': 'reshmi__resmi'}, {'full_name': 'Vinzen Rachel Mathew', 'id': '6157302730', 'is_verified': False, 'profile_pic_url': 'https://scontent-cdg4-1.cdninstagram.com/v/t51.2885-19/473047170_1286249202699461_5404447944426821169_n.jpg?stp=dst-jpg_s150x150_tt6&_nc_ht=scontent-cdg4-1.cdninstagram.com&_nc_cat=105&_nc_oc=Q6cZ2AG-pJ9St-XZOZTLGJZAR9JsxokFlfPdSFJI3NzhO0nkwBz23IJDea-HsGmUbkkQ7ZM&_nc_ohc=liglR3jrMSIQ7kNvgHow3X_&_nc_gid=b03907e7804148aea4ed56769004bcde&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYAcQypY2a2d-A8KZFn5Mwa-QBoFMxRp36taww9EuZOGiw&oe=67B8E4F5&_nc_sid=10d13b', 'username': 'vinz_rac'}], 'child_posts': []}, {'id': '3586730364359268034', 'shortCode': 'DHGoENYvdbC', 'caption': '#보넥도짤\n.\n.\n.\n #보이넥스트도어 #보넥도 #boynextdoor #태산 #이한 #재현 #리우 #성호 #운학 #케이팝 #kpop #아이돌 #팬계정 #id ...
# Response saved to apify_trending_posts_byhashtag.json

# %% [markdown]
# ## Instagram Posts Search by Username Crawler

# %%
import requests
import json

username = "klp48"
date = None
max_username = 3
max_posts_per_username = 2
url = "http://localhost:8000/instagram/posts/search/by-username"

params = {"username": username, "max_username": max_username, "max_posts_per_username": max_posts_per_username, "start_date": date}


try:
    response = requests.get(url, params=params, verify=False)

    if response.status_code == 200:
        data = response.json()
        print("Response:", data)

        # Save data to a JSON file
        file_name = f"apify_posts_by_username.json"
        with open(file_name, "w", encoding="utf-8") as json_file:
            json.dump(data, json_file, indent=4, ensure_ascii=False)

        print(f"Response saved to {file_name}")

    else:
        print(f"Error: {response.status_code}, Message: {response.text}")

except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")
# Out:
# Response: {'posts': [{'id': '', 'shortCode': '', 'caption': '', 'commentsCount': 0, 'dimensionsHeight': 0, 'dimensionsWidth': 0, 'displayUrl': '', 'likesCount': 0, 'timestamp': '', 'owner': {'id': '', 'username': '', 'full_name': ''}, 'usertags': '', 'child_posts': []}, {'id': '3360244689260870967', 'shortCode': 'C6h_L3VyX03', 'caption': 'โครงการบ้านกาญจนดิษฐ์\n✨ บ้านเดี่ยวเริ่มต้นเพียง 2,XXX,XXX.- บาท ✨\n\n🌳🛏️ 2 ห้องนอน🛁 2 ห้องน้ำ\n🍳 2 ห้องครัว🛋️ 1 ห้องนั่งเล่น\n🚗 2 ที่จอดรถ\n\n📣📣 ติดต่อสอบถาม 📣📣 \n095-9795001 (เซลล์เจ้าโอ๊ะ)📞\n\n◾พนักงานประจำ พนักงานบริษัทอาชีพอิสระ เจ้าของกิจการ\n◾พ่อค้า แม่ค้า ออนไลน์ / ผู้รับเหมา\n◾ให้คำปรึกษาและช่วยแก้ไขปัญหาสถานะเครดิตบูโร😎\n\n#บ้านกาญจนดิษฐ์\u200b #บ้านเดี่ยวคุณภาพ\n#บ้าน #บ้านโมเดิร์น #บ้านสวย #บ้านกาญจนดิษฐ์ #บ้านในสุราษฎร์ #บ้านทำเลดี #บ้านและสวน #บ้านเดี่ยว #บ้านในเมือง #กาญจนดิษฐ์', 'commentsCount': 0, 'dimensionsHeight': 1080, 'dimensionsWidth': 1080, 'displayUrl': 'https://instagram.fagc3-2.fna.fbcdn.net/v/t51.29350-15/441164469_1694586391076369_4013868791504838687_n.jpg?stp=dst-jpg_e35_s1080x1080_tt6&_nc_ht=instagram.fagc3-2.fna.fbcdn.net&_nc_cat=105&_nc_oc=Q6cZ2AFtg7JzZfTa3-0Qs8xbnR4hKmoT-JusWDWtZFbBgPa8EFYGz1rdZINZq7j4TD9VYa8&_nc_ohc=-rpyQ_3Hd5sQ7kNvgHRX62e&_nc_gid=f1dc43c89de14029a1999703de7ae04a&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYDvMrQHfzqg5XMXPxBGUVhaqvU2y-G7_PkGHgJgQlbFtA&oe=67B8C755&_nc_sid=10d13b', 'likesCount': 3, 'timestamp': '2024-05-04T03:13:23.000Z', 'owner': {'id': '66544905555', 'username': 'bannkajanadit_', 'full_name': 'โครงการบ้านกาญจนดิษฐ์'}, 'usertags': [{'full_name': 'ᴼᴬᴴ ᴷᵃⁿᵃʳᵘᵗ', 'id': '341932479', 'is_verified': False, 'profile_pic_url': 'https://instagram.fagc3-1.fna.fbcdn.net/v/t51.2885-19/469393781_1097819061519979_7467326812838635436_n.jpg?stp=dst-jpg_s150x150_tt6&_nc_ht=instagram.fagc3-1.fna.fbcdn.net&_nc_cat=107&_nc_oc=Q6cZ2AFtg7JzZfTa3-0Qs8xbnR4hKmoT-JusWDWtZFbBgPa8EFYGz1rdZINZq7j4TD9VYa8&_nc_ohc=ougoMm5Fw_0Q7kNvgEOhthB&_nc_gid=f1dc43c89de14029a1999703de7ae04a&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYBcAr0XS_lGHpr8wxV_EAKpHdbWw4I_vPgx5OrG137C7Q&oe=67B8EF09&_nc_sid=10d13b', 'username': 'me.kanarut'}], 'child_posts': [{'id': '3360244680150966908', 'displayUrl': 'https://instagram.fagc3-2.fna.fbcdn.net/v/t51.29350-15/441164469_1694586391076369_4013868791504838687_n.jpg?stp=dst-jpg_e35_s1080x1080_tt6&_nc_ht=instagram.fagc3-2.fna.fbcdn.net&_nc_cat=105&_nc_oc=Q6cZ2AFtg7JzZfTa3-0Qs8xbnR4hKmoT-JusWDWtZFbBgPa8EFYGz1rdZINZq7j4TD9VYa8&_nc_ohc=-rpyQ_3Hd5sQ7kNvgHRX62e&_nc_gid=f1dc43c89de14029a1999703de7ae04a&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYDvMrQHfzqg5XMXPxBGUVhaqvU2y-G7_PkGHgJgQlbFtA&oe=67B8C755&_nc_sid=10d13b'}, {'id': '3360244680092053362', 'displayUrl': 'https://instagram.fagc3-2.fna.fbcdn.net/v/t51.29350-15/441259422_450472584336471_7790742214629765805_n.jpg?stp=dst-jpg_e35_s1080x1080_tt6&_nc_ht=instagram.fagc3-2.fna.fbcdn.net&_nc_cat=103&_nc_oc=Q6cZ2AFtg7JzZfTa3-0Qs8xbnR4hKmoT-JusWDWtZFbBgPa8EFYGz1rdZINZq7j4TD9VYa8&_nc_ohc=RVBtY_zOe8UQ7kNvgEMkqSI&_nc_gid=f1dc43c89de14029a1999703de7ae04a&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYBLQJHYkefRqptQRN0XSzw4vQVJIFTzFLv8lZmJWwKikg&oe=67B8E8A7&_nc_sid=10d13b'}, {'id': '3360244680083742809', 'displayUrl': 'https://instagram.fagc3-1.fna.fbcdn.net/v/t51.29350-15/441325835_452176850606498_3625774573499065842_n.jpg?stp=dst-jpg_e35_s1080x1080_tt6&_nc_ht=instagram.fagc3-1.fna.fbcdn.net&_nc_cat=102&_nc_oc=Q6cZ2AFtg7JzZfTa3-0Qs8xbnR4hKmoT-JusWDWtZFbBgPa8EFYGz1rdZINZq7j4TD9VYa8&_nc_ohc=Zfc-wb2Qcv0Q7kNvgFjfjfP&_nc_gid=f1dc43c89de14029a1999703de7ae04a&edm=APs17CUBAAAA&ccb=7-5&oh=00_AYACSuM7qaR1qE-unk7AJhtI5SoewIAIf_HBChcr9k1EcA&oe=67B8E910&_nc_sid=10d13b'}, {'id': '3360244680092226736', 'displayUrl': 'https://instagram.fagc3-2.fna.fbcdn.net/v/t51.29350-15/441500080_3650066555270712_2183507023879433989_n.jpg?stp=dst-jpg_e35_s1080x1080_tt6&_nc_ht=instagram.fagc3-2.fna.fbcdn.net&_nc_cat=100&_nc_oc=Q6cZ2AFtg7JzZfTa3-0Qs8xbnR4hKmoT-JusWDWtZFbBgPa8EFYGz1rdZINZq7j4TD9VYa8&_nc_ohc=lK1smTdvxMMQ7kNvgG0atlE&_nc_gid=f1dc43c89de14029a1999703de7ae04a&edm=APs ...
# Response saved to apify_posts_by_username.json
