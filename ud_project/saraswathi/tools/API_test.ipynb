# %% [markdown]
# # Feedback API

# %% [markdown]
# ## Save

# %%
import requests

response = requests.put(
    "http://localhost:8000/feedback/save",
    # "https://dev.ada-app.ai/saraswatimvp2/feedback/save",
    json={
        "chart_id": "442b2d55-b758-42a9-8b84-0f1a90251f68", 
        "like": "false", 
        "feedback": {
            "chart_title": {
                "selected_options": ["Irrelevant to my question", "Too long"], 
                "other": "The title should be more concise and specific."
            }, 
            "xaxis_title": {
                "selected_options": ["Not descriptive enough"], 
                "other": ""
            }, 
            "yaxis_title": {
                "selected_options": ["Too short"], 
                "other": "Consider adding units for clarity."
            },
            "zaxis_title": {
                "selected_options": ["Too short"], 
                "other": "Consider adding units for clarity."
            }, 
            "xaxis_data": {
                "selected_options": ["Data misrepresented"], 
                "other": ""
            }, 
            "yaxis_data": {
                "selected_options": [], 
                "other": "Data points should reflect recent data."
            }, 
            "zaxis_data": {
                "selected_options": [], 
                "other": "Data points should reflect recent data."
            }, 
            "overall_chart": {
                "selected_options": ["Poor labelling"], 
                "other": "Make the chart easier to understand at a glance."
            }
        }
    },
    verify=False,
)

response.status_code
# Out:
# 200

# %% [markdown]
# ## Load

# %%
import requests

response = requests.get(
    "http://localhost:8000/feedback/chart_id/442b2d55-b758-42a9-8b84-0f1a90251f68",
)

response.status_code
# Out:
# 200

# %% [markdown]
# ## General SQL Query Generator and Extractor

# %%
import requests
url = 'http://localhost:8000/sql/query_generator_executor'
# url = 'https://dev.ada-app.ai/saraswatimvp2/sql/query_generator_executor'
params = {
    'user_intent': 'CASA Product penetration and the KPI is Projected Home Loan Penetration Value',    
    'database_name': "ada_banks_data_asset",    
    'table_name': 'report_cross_selling_performance_product_type_new',    
    'db_tag': "label1",
    "session_id": "161a3eb9-bd2e-40c1-9ad3-c35159113b37",
    }
response = requests.post(url, params=params, verify=False)
if response.status_code == 500:
    error_message = response.json().get("detail", "Unknown error")
    print(error_message)
else:
    response_data = response.json()
    print(response_data)
# Out:
# {'Chart_Query': "SELECT      COUNT(CASE WHEN has_current_account = 'TRUE' THEN ID END) AS CASA_Penetration,     COUNT(CASE WHEN has_loan = 'TRUE' THEN ID END) AS Home_Loan_Penetration,     COUNT(CASE WHEN has_current_account = 'TRUE' AND has_loan = 'TRUE' THEN ID END) AS Projected_Home_Loan_Penetration_Value FROM      ada_banks_data_asset.report_cross_selling_performance_product_type_new;", 'data': [{'CASA_Penetration': 852850, 'Home_Loan_Penetration': 390776, 'Projected_Home_Loan_Penetration_Value': 263886}]}

# %% [markdown]
# # MySQL Streaming

# %%
import requests
import ast
import json

# Brahmaputra input: get me trend analysis and aggregate by product

response = requests.post(
    "http://ae5165e30a2374cffac790c233cf33b6-734568920.ap-southeast-1.elb.amazonaws.com:8000/streaming/GraphUpsSummary/d3",
    json=[
        "ada_banks_data_asset.report_cross_selling_performance_product_type_new",
        "label1",
        " The user's primary intent is to analyze the product penetration rate based on the 'Income Level' dimension of the 'Customer Financial Product Usage Analysis' table. They have implicitly requested to view or examine the data grouped by income levels. The user is currently awaiting the delivery of a customized data asset visualization that focuses on the specified income range to gain insights into the product usage trends among different income groups.",
        {},
        [
            "income_level"
        ],
        "\"starhub_001\"",
        "\"goldius.leo@userdata.tech\"",
        "\"6cacaafc-c85c-4dd0-b9f3-c323f458b60a\""
    ],
    stream=True,
    # headers = {
    #     'Content-Type': 'application/json',
    #     'accept': 'application/json'
    # },
    verify=False,
)

chunk_idx = 1

for chunk in response.iter_content(10000000000):
    # display(chunk.decode("utf-8"))
    if ast.literal_eval(chunk.decode("utf-8"))["data"]["type"] == "result":
        with open(f"test1-{chunk_idx}.json", "w") as f:
            json.dump(ast.literal_eval(chunk.decode("utf-8")), f)

        chunk_idx += 1

# print(f"respone code: {response.status_code}")
# display(ast.literal_eval(response.content.decode("utf-8")))
# Out:
# '{"data": {"type": "info", "message": "Downloading table metadata."}}\r\n'
# '{"data": {"type": "info", "message": "Orchestrating chart flow and questions aligned with your intent."}}\r\n'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 31
#       7 response = requests.post(
#       8     "http://ae5165e30a2374cffac790c233cf33b6-734568920.ap-southeast-1.elb.amazonaws.com:8000/streaming/GraphUpsSummary/d3",
#       9     json=[
#    (...)
#      26     verify=False,
#      27 )
#      29 chunk_idx = 1
# ---> 31 for chunk in response.iter_content(10000000000):
#      32     display(chunk.decode("utf-8"))
#      33     if ast.literal_eval(chunk.decode("utf-8"))["data"]["type"] == "result":
#
# File ~/miniconda3/envs/saraswathi/lib/python3.9/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/miniconda3/envs/saraswathi/lib/python3.9/site-packages/urllib3/response.py:1063, in HTTPResponse.stream(self, amt, decode_content)
#    1047 """
#    1048 A generator wrapper for the read() method. A call will block until
#    1049 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1060     'content-encoding' header.
#    1061 """
#    1062 if self.chunked and self.supports_chunked_reads():
# -> 1063     yield from self.read_chunked(amt, decode_content=decode_content)
#    1064 else:
#    1065     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/miniconda3/envs/saraswathi/lib/python3.9/site-packages/urllib3/response.py:1219, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1216     amt = None
#    1218 while True:
# -> 1219     self._update_chunk_length()
#    1220     if self.chunk_left == 0:
#    1221         break
#
# File ~/miniconda3/envs/saraswathi/lib/python3.9/site-packages/urllib3/response.py:1138, in HTTPResponse._update_chunk_length(self)
#    1136 if self.chunk_left is not None:
#    1137     return None
# -> 1138 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1139 line = line.split(b";", 1)[0]
#    1140 try:
#
# File ~/miniconda3/envs/saraswathi/lib/python3.9/socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # Data Asset Table

# %%
import requests
import ast
import json

response = requests.post(
    "http://localhost:8000/DataAssetTable",
    json=[
        "ada_banks_data_asset.report_cross_selling_performance_product_type_new",
        "label1",
        " The user's primary intent is to analyze the product penetration rate based on the 'Income Level' dimension of the 'Customer Financial Product Usage Analysis' table. They have implicitly requested to view or examine the data grouped by income levels. The user is currently awaiting the delivery of a customized data asset visualization that focuses on the specified income range to gain insights into the product usage trends among different income groups.",
        {},
        [
            "income_level"
        ],
        "\"starhub_001\"",
        "\"goldius.leo@userdata.tech\"",
        "\"6cacaafc-c85c-4dd0-b9f3-c323f458b60a\""
    ],
    stream=False,
    headers={"Content-Type": "application/json", "accept": "application/json"},
    verify=False,
)

# for chunk in response.iter_content(100000000):
#     print(ast.literal_eval(chunk.decode("utf-8")))

with open("test.json", "w") as f:
    json.dump(ast.literal_eval(response.content.decode("utf-8")), f)

print(f"respone code: {response.status_code}")
display(ast.literal_eval(response.content.decode("utf-8")))

# %% [markdown]
# # MySQL Table Joined Flow

# %%
import requests
import ast

response = requests.post(
    "http://localhost:8000/GraphUpsSummary",
    json=[
        "I want to get customer transaction analysis",
        [
            {
                "Table_A": "blueriver_rdbms.trx_07_data",
                "Table_B": "blueriver_rdbms.customer_05_2024",
                "Join_Key": "customer_ID",
                "Join_Type": "LEFT JOIN",
                "SQL_Query": "SELECT blueriver_rdbms.trx_07_data.account_id, blueriver_rdbms.trx_07_data.account_type, blueriver_rdbms.trx_07_data.branch_name, blueriver_rdbms.trx_07_data.customer_ID, blueriver_rdbms.trx_07_data.first_name, blueriver_rdbms.trx_07_data.last_name, blueriver_rdbms.trx_07_data.transaction_amount, blueriver_rdbms.trx_07_data.transaction_date, blueriver_rdbms.trx_07_data.transaction_description, blueriver_rdbms.trx_07_data.transaction_id, blueriver_rdbms.trx_07_data.transaction_type, COALESCE(blueriver_rdbms.customer_05_2024.bank_account_id, NULL) AS bank_account_id, COALESCE(blueriver_rdbms.customer_05_2024.company_name, NULL) AS company_name, COALESCE(blueriver_rdbms.customer_05_2024.email, NULL) AS email, COALESCE(blueriver_rdbms.customer_05_2024.gender, NULL) AS gender, COALESCE(blueriver_rdbms.customer_05_2024.job_title, NULL) AS job_title FROM blueriver_rdbms.trx_07_data LEFT JOIN blueriver_rdbms.customer_05_2024 ON blueriver_rdbms.trx_07_data.customer_ID = blueriver_rdbms.customer_05_2024.customer_ID;",
                "Database_Name": "MySQL",
                "Table_Relation": "PK",
                "Confidence_Rank": 1,
                "Confidence_Score": 0.7238618537278425,
                "Table_A_Name_noDB": "trx_07_data",
                "Table_B_Name_noDB": "customer_05_2024",
                "Table_Level_Metadata": [
                    {
                        "source": "N/A",
                        "table_name": "trx_07_data",
                        "table_type": "FACT",
                        "column_list": "account_id|account_type|branch_name|customer_ID|first_name|last_name|transaction_amount|transaction_date|transaction_description|transaction_id|transaction_type",
                        "foreign_key": "N/A",
                        "primary_key": "N/A",
                        "table_match": "blueriver_rdbms.trx_07_data",
                        "database_name": "blueriver_rdbms",
                        "row_description": " The row represents an online transaction of $99,267.67 from the Nantes branch by Maryjo Ellingsworth (customer ID 73-3680662) on June 12, 2023, which was a withdrawal, as indicated by the transaction type.",
                        "number_of_columns": "11",
                        "sql_database_name": "MySQL",
                        "table_description": ' The "trx_07_data" table is a fact table that captures detailed transaction data for July, encompassing account, customer, and transaction-related information. It includes essential identifiers such as account ID, account type, branch name, customer ID, first name, last name, and transaction type. The table records transaction amounts and dates, along with descriptions, providing a comprehensive view of transaction activities. This table is instrumental in generating transaction-based reports, facilitating financial analysis, and supporting strategic decision-making for the specified period. This table contains transactional data with columns for account information (account_id, account_type, branch_name), customer identification (customer_ID, first_name, last_name), and transaction details (transaction_amount, transaction_date, transaction_description, transaction_type). The KPIs that can be calculated from this table include Customer Payment Performance, Accounts Receivable Aging Report, Average Billing Amount per Customer, and Customer Segmentation based on interests.',
                        "database_identifier": "label1",
                        "last_metadata_update": "2024-07-16 13:05:57",
                        "table_short_description": ' The "trx_07_data" table is a fact table capturing detailed transaction data for July, including account, customer, and transaction-related information. This table is essential for generating transaction-based reports, facilitating financial analysis, and supporting strategic decision-making, with KPIs such as Customer Payment Performance and Accounts Receivable Aging Report.',
                    },
                    {
                        "source": "N/A",
                        "table_name": "customer_05_2024",
                        "table_type": "DIMENSION",
                        "column_list": "bank_account_id|company_name|customer_ID|email|first_name|gender|job_title|last_name",
                        "foreign_key": "N/A",
                        "primary_key": "N/A",
                        "table_match": "blueriver_rdbms.customer_05_2024",
                        "database_name": "blueriver_rdbms",
                        "row_description": " The row represents a customer, Sheelagh Harral, with ID 45-9343936, associated with company 9936, and having the email [sharral1@earthlink.net](mailto:sharral1@earthlink.net). She is a female Environmental Tech and her gender is BZNJ, with the bank account ID FR10 and last name Harral.",
                        "number_of_columns": "8",
                        "sql_database_name": "MySQL",
                        "table_description": ' The "customer_05_2024" table is a dimension table that stores detailed customer information for May 2024, including bank account IDs, company names, customer IDs, email addresses, first and last names, job titles, and genders. This table is essential for maintaining an up-to-date customer database for the specified month, aiding in personalized marketing, customer relationship management, and sales analytics. By providing comprehensive customer profiles, it supports targeted customer analysis and strategic decision-making for May 2024. This table is a crucial component for understanding customer demographics and behavior, enabling organizations to optimize their marketing strategies and improve overall customer satisfaction. This table contains customer information with the following columns: Bank_Account_ID, company_name, customer_ID, email, first_name, gender, job_title, and last_name. The KPIs that can be calculated from this table include Customer Payment Performance, Accounts Receivable Aging Report, Average Billing Amount per Customer, and Customer Segmentation (Interests).',
                        "database_identifier": "label1",
                        "last_metadata_update": "2024-07-16 13:05:57",
                        "table_short_description": ' The "customer_05_2024" table is a dimension table that stores detailed customer information for May 2024, enabling targeted customer analysis and strategic decision-making. It provides comprehensive customer profiles, aiding in personalized marketing, customer relationship management, and sales analytics, and allows for calculating KPIs such as Customer Payment Performance and Accounts Receivable Aging Report.',
                    },
                ],
                "Column_Level_Metadata": [
                    {
                        "n_unique": 966,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": 375081948390421900,
                        "max_value": 6771676543769412000,
                        "min_value": 4017950000000,
                        "row_count": 1000,
                        "std_value": 1365162670797093600,
                        "10_samples": "4017950000000|4041380000000|4041590000000|4041600000000|4064400000000|4416010000000|4952670000000|30018300000000|30023900000000|30024500000000",
                        "data_tribe": "id",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "double",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Account ID",
                        "cleaned_column_name": "account_id",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.966,
                        "original_sql_column_name": "account_id",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.account_id",
                    },
                    {
                        "n_unique": 10,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "basic|business|corporate|current|joint|online|personal|retirement|savings|student",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Payment Performance, Acounts Receivable Aging Report, Average Billing Amount per Customer",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Account Type",
                        "cleaned_column_name": "account_type",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Has_Current_Account_Flag",
                        "n_unique_per_row_count": 0.01,
                        "original_sql_column_name": "account_type",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.account_type",
                    },
                    {
                        "n_unique": 984,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "‘Aqrah|Afareaitu|Aghada|Agía Varvára|Ágios Spyrídon|Água Retorta|Aimorés|Aix-en-Provence|Aiximan|Akureyri",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Branch Name",
                        "cleaned_column_name": "branch_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.984,
                        "original_sql_column_name": "branch_name",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.branch_name",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "00-1662667|00-3418626|00-4722195|00-5362154|00-5585088|00-5655982|00-6292647|00-6881844|00-7943937|00-7997137",
                        "data_tribe": "id",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Customer ID",
                        "cleaned_column_name": "customer_ID",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "customer_ID",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.customer_ID",
                    },
                    {
                        "n_unique": 950,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Aaren|Abby|Abe|Ada|Adelaida|Adelind|Adlai|Adolf|Adrea|Adriaens",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "First Name",
                        "cleaned_column_name": "first_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.95,
                        "original_sql_column_name": "first_name",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.first_name",
                    },
                    {
                        "n_unique": 986,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Abbati|Abrahamsson|Abrams|Ackenhead|Adame|Adamiak|Adamsen|Adriaens|Aim|Aitchison",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Last Name",
                        "cleaned_column_name": "last_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.986,
                        "original_sql_column_name": "last_name",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.last_name",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "$10114.83|$10386.81|$10522.75|$10574.60|$10767.90|$10774.89|$10821.90|$10828.69|$10949.39|$11266.24",
                        "data_tribe": "numerical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Payment Performance, Acounts Receivable Aging Report, Average Billing Amount per Customer",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Transaction Amount",
                        "cleaned_column_name": "transaction_amount",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Transaction_Channel",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "transaction_amount",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.transaction_amount",
                    },
                    {
                        "n_unique": 596,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "01/01/2023|01/01/2024|01/02/2023|01/02/2024|01/03/2022|01/03/2023|01/03/2024|01/04/2022|01/05/2024|01/06/2022",
                        "data_tribe": "date_related",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Transaction Date",
                        "cleaned_column_name": "transaction_date",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Industry",
                        "n_unique_per_row_count": 0.596,
                        "original_sql_column_name": "transaction_date",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.transaction_date",
                    },
                    {
                        "n_unique": 22,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Automotive|Baby|Beauty|Books|Clothing|Computers|Electronics|Games|Garden|Grocery",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Payment Performance, Acounts Receivable Aging Report, Average Billing Amount per Customer",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Transaction Description",
                        "cleaned_column_name": "transaction_description",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Transaction_Channel",
                        "n_unique_per_row_count": 0.022,
                        "original_sql_column_name": "transaction_description",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.transaction_description",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "AD29 6650 2328 YTPS WRLO VLQN|AD54 6453 8754 6ZFA YXOP TMAW|AD62 7546 5974 YN6G AFJ0 IK6J|AD69 0563 0984 AV0T FRBA WWMR|AD71 8115 8430 7ZMA OLJQ J3RT|AD77 9386 3661 CASI JVIN WP0M|AD82 8103 2448 WFUE XCSW ZAEJ|AD85 6098 7347 IMRF P4LS 5IAC|AD96 7383 4000 AXLH ICZR 84FD|AE11 7305 4601 5159 2238 126",
                        "data_tribe": "id",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Transaction ID",
                        "cleaned_column_name": "transaction_id",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Transactions_Type",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "transaction_id",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.transaction_id",
                    },
                    {
                        "n_unique": 10,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "deposit|donation|exchange|fee|loan|purchase|refund|subscription|transfer|withdrawal",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Transaction Type, a categorical value that describes the type of financial transaction, such as deposit, donation, exchange, fee, loan, purchase, refund, subscription, transfer, or withdrawal.",
                        "column_description": "Transaction Type",
                        "cleaned_column_name": "transaction_type",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Transactions_Type",
                        "n_unique_per_row_count": 0.01,
                        "original_sql_column_name": "transaction_type",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.transaction_type",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "AD05 9959 2223 FWEC XJR4 QKGI|AD14 4707 7001 1ZVZ IRSY XPDN|AD17 3872 7448 BGSG 6ADT OGAB|AD25 0190 8133 63HC LHXW XWXQ|AD27 3598 0778 8JBK V9VC ZLNK|AD31 6483 0114 YD6U OTM5 N5NG|AD35 0143 4996 VN73 CD6K QIHV|AD55 6367 6729 ORHL Z2IE VFUI|AD70 2464 9693 2AU1 APBU WVCS|AD74 9377 4714 0QN9 LIXG UYWJ",
                        "data_tribe": "id",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Payment Performance, Acounts Receivable Aging Report, Average Billing Amount per Customer",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Bank Account ID is a unique identifier for a customer's bank account, consisting of a combination of letters and numbers, which is used to facilitate financial transactions.",
                        "column_description": "Bank Account ID",
                        "cleaned_column_name": "bank_account_id",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Has_Current_Account_Flag",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "bank_account_id",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.bank_account_id",
                    },
                    {
                        "n_unique": 362,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Abata|Agimba|Aibox|Ailane|Aimbo|Aimbu|Ainyx|Aivee|Avamba|Avamm",
                        "data_tribe": "categorical",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Company Name refers to the name of the company where the customer is employed, providing context for the customer's job title and role.",
                        "column_description": "Company Name",
                        "cleaned_column_name": "company_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Industry",
                        "n_unique_per_row_count": 0.362,
                        "original_sql_column_name": "company_name",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.company_name",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "00-1033717|00-1499639|00-1537576|00-2364491|00-2435085|00-2602569|00-3463157|00-6079924|00-6843781|00-6930131",
                        "data_tribe": "id",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Customer ID is a unique identifier assigned to each customer, allowing for easy tracking and management of customer information and transactions.",
                        "column_description": "Customer ID",
                        "cleaned_column_name": "customer_ID",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "customer_ID",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.customer_ID",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "aaxcell8q@dagondesign.com|abaldingq@jalbum.net|abanbrookgz@a8.net|abantingh2@desdev.cn|abishopppg@boston.com|aboakesoj@rakuten.co.jp|abroseman9h@google.pl|abubbinsqs@twitpic.com|acamelian9@umich.edu|acaserls@sohu.com",
                        "data_tribe": "textual",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Email is the electronic mail address of the customer, used for communication and electronic transactions.",
                        "column_description": "Email",
                        "cleaned_column_name": "email",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "email",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.email",
                    },
                    {
                        "n_unique": 946,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Aarika|Ab|Abdel|Abigale|Abram|Adah|Adelice|Adriaens|Adrianne|Adriano",
                        "data_tribe": "categorical",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "First Name is the given name of the customer, representing the initial part of their personal identity.",
                        "column_description": "First Name",
                        "cleaned_column_name": "first_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.946,
                        "original_sql_column_name": "first_name",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.first_name",
                    },
                    {
                        "n_unique": 8,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Agender|Bigender|Female|Genderfluid|Genderqueer|Male|Non-binary|Polygender",
                        "data_tribe": "categorical",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Gender is the self-identified gender of the customer, which can include various categories such as Female, Male, Agender, Bigender, Genderfluid, Genderqueer, Non-binary, Polygender, etc.",
                        "column_description": "Gender",
                        "cleaned_column_name": "gender",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.008,
                        "original_sql_column_name": "gender",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.gender",
                    },
                    {
                        "n_unique": 180,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Account Coordinator|Account Executive|Account Representative I|Account Representative II|Account Representative III|Account Representative IV|Accountant I|Accountant III|Accountant IV|Accounting Assistant I",
                        "data_tribe": "categorical",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Job Title is the official title of the customer's position within their company, reflecting their role and responsibilities.",
                        "column_description": "Job Title",
                        "cleaned_column_name": "job_title",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.18,
                        "original_sql_column_name": "job_title",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.job_title",
                    },
                    {
                        "n_unique": 989,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Abelov|Abelovitz|Abethell|Achromov|Adnams|Adolfsen|Adshede|Advani|Akester|Albany",
                        "data_tribe": "categorical",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Last Name is the family name or surname of the customer, representing the final part of their personal identity.",
                        "column_description": "Last Name",
                        "cleaned_column_name": "last_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.989,
                        "original_sql_column_name": "last_name",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.last_name",
                    },
                ],
                "Combined_LLM_Description": "This table is a comprehensive data asset, merging transaction data from 'trx_07_data' with customer information from 'customer_05_2024'. It facilitates in-depth transactional and customer analysis, supporting strategic decision-making and enhancing financial, marketing, and sales performance insights.",
            }
        ],
        "starhub_001",
        "goldius.leo@userdata.tech",
        "I'd be happy to assist you with customer transaction analysis. To provide a comprehensive analysis, I'll need to join the necessary tables. Please note that this may take some time.\n\nOnce completed, I will generate relevant charts and insights to help you better understand your customers' transaction patterns. You can expect to see information on:\n\n* Customer demographics\n* Transaction frequency and value\n* Product popularity and trends\n* Geographic distribution of customers\n\nPlease stand by while I work on generating the analysis. I'll",
    ],
    stream=False,
    headers={"Content-Type": "application/json", "accept": "application/json"},
    verify=False,
)

# for chunk in response.iter_content(100000000):
#     print(ast.literal_eval(chunk.decode("utf-8")))

print(f"respone code: {response.status_code}")
display(ast.literal_eval(response.content.decode("utf-8")))

# %%
import requests
import ast

response = requests.post(
    "http://localhost:8000/GraphUpsSummary",
    json=[
        "I want to get customer transaction analysis",
        [
            {
                "Table_A": "blueriver_rdbms.trx_07_data",
                "Table_B": "blueriver_rdbms.customer_05_2024",
                "Join_Key": "customer_ID",
                "Join_Type": "LEFT JOIN",
                "SQL_Query": "SELECT blueriver_rdbms.trx_07_data.account_id, blueriver_rdbms.trx_07_data.account_type, blueriver_rdbms.trx_07_data.branch_name, blueriver_rdbms.trx_07_data.customer_ID, blueriver_rdbms.trx_07_data.first_name, blueriver_rdbms.trx_07_data.last_name, blueriver_rdbms.trx_07_data.transaction_amount, blueriver_rdbms.trx_07_data.transaction_date, blueriver_rdbms.trx_07_data.transaction_description, blueriver_rdbms.trx_07_data.transaction_id, blueriver_rdbms.trx_07_data.transaction_type, COALESCE(blueriver_rdbms.customer_05_2024.bank_account_id, NULL) AS bank_account_id, COALESCE(blueriver_rdbms.customer_05_2024.company_name, NULL) AS company_name, COALESCE(blueriver_rdbms.customer_05_2024.email, NULL) AS email, COALESCE(blueriver_rdbms.customer_05_2024.gender, NULL) AS gender, COALESCE(blueriver_rdbms.customer_05_2024.job_title, NULL) AS job_title FROM blueriver_rdbms.trx_07_data LEFT JOIN blueriver_rdbms.customer_05_2024 ON blueriver_rdbms.trx_07_data.customer_ID = blueriver_rdbms.customer_05_2024.customer_ID;",
                "Database_Name": "MySQL",
                "Table_Relation": "PK",
                "Confidence_Rank": 1,
                "Confidence_Score": 0.7238618537278425,
                "Table_A_Name_noDB": "trx_07_data",
                "Table_B_Name_noDB": "customer_05_2024",
                "Table_Level_Metadata": [
                    {
                        "source": "N/A",
                        "table_name": "trx_07_data",
                        "table_type": "FACT",
                        "column_list": "account_id|account_type|branch_name|customer_ID|first_name|last_name|transaction_amount|transaction_date|transaction_description|transaction_id|transaction_type",
                        "foreign_key": "N/A",
                        "primary_key": "N/A",
                        "table_match": "blueriver_rdbms.trx_07_data",
                        "database_name": "blueriver_rdbms",
                        "row_description": " The row represents an online transaction of $99,267.67 from the Nantes branch by Maryjo Ellingsworth (customer ID 73-3680662) on June 12, 2023, which was a withdrawal, as indicated by the transaction type.",
                        "number_of_columns": "11",
                        "sql_database_name": "MySQL",
                        "table_description": ' The "trx_07_data" table is a fact table that captures detailed transaction data for July, encompassing account, customer, and transaction-related information. It includes essential identifiers such as account ID, account type, branch name, customer ID, first name, last name, and transaction type. The table records transaction amounts and dates, along with descriptions, providing a comprehensive view of transaction activities. This table is instrumental in generating transaction-based reports, facilitating financial analysis, and supporting strategic decision-making for the specified period. This table contains transactional data with columns for account information (account_id, account_type, branch_name), customer identification (customer_ID, first_name, last_name), and transaction details (transaction_amount, transaction_date, transaction_description, transaction_type). The KPIs that can be calculated from this table include Customer Payment Performance, Accounts Receivable Aging Report, Average Billing Amount per Customer, and Customer Segmentation based on interests.',
                        "database_identifier": "label1",
                        "last_metadata_update": "2024-07-16 13:05:57",
                        "table_short_description": ' The "trx_07_data" table is a fact table capturing detailed transaction data for July, including account, customer, and transaction-related information. This table is essential for generating transaction-based reports, facilitating financial analysis, and supporting strategic decision-making, with KPIs such as Customer Payment Performance and Accounts Receivable Aging Report.',
                    },
                    {
                        "source": "N/A",
                        "table_name": "customer_05_2024",
                        "table_type": "DIMENSION",
                        "column_list": "bank_account_id|company_name|customer_ID|email|first_name|gender|job_title|last_name",
                        "foreign_key": "N/A",
                        "primary_key": "N/A",
                        "table_match": "blueriver_rdbms.customer_05_2024",
                        "database_name": "blueriver_rdbms",
                        "row_description": " The row represents a customer, Sheelagh Harral, with ID 45-9343936, associated with company 9936, and having the email [sharral1@earthlink.net](mailto:sharral1@earthlink.net). She is a female Environmental Tech and her gender is BZNJ, with the bank account ID FR10 and last name Harral.",
                        "number_of_columns": "8",
                        "sql_database_name": "MySQL",
                        "table_description": ' The "customer_05_2024" table is a dimension table that stores detailed customer information for May 2024, including bank account IDs, company names, customer IDs, email addresses, first and last names, job titles, and genders. This table is essential for maintaining an up-to-date customer database for the specified month, aiding in personalized marketing, customer relationship management, and sales analytics. By providing comprehensive customer profiles, it supports targeted customer analysis and strategic decision-making for May 2024. This table is a crucial component for understanding customer demographics and behavior, enabling organizations to optimize their marketing strategies and improve overall customer satisfaction. This table contains customer information with the following columns: Bank_Account_ID, company_name, customer_ID, email, first_name, gender, job_title, and last_name. The KPIs that can be calculated from this table include Customer Payment Performance, Accounts Receivable Aging Report, Average Billing Amount per Customer, and Customer Segmentation (Interests).',
                        "database_identifier": "label1",
                        "last_metadata_update": "2024-07-16 13:05:57",
                        "table_short_description": ' The "customer_05_2024" table is a dimension table that stores detailed customer information for May 2024, enabling targeted customer analysis and strategic decision-making. It provides comprehensive customer profiles, aiding in personalized marketing, customer relationship management, and sales analytics, and allows for calculating KPIs such as Customer Payment Performance and Accounts Receivable Aging Report.',
                    },
                ],
                "Column_Level_Metadata": [
                    {
                        "n_unique": 966,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": 375081948390421900,
                        "max_value": 6771676543769412000,
                        "min_value": 4017950000000,
                        "row_count": 1000,
                        "std_value": 1365162670797093600,
                        "10_samples": "4017950000000|4041380000000|4041590000000|4041600000000|4064400000000|4416010000000|4952670000000|30018300000000|30023900000000|30024500000000",
                        "data_tribe": "id",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "double",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Account ID",
                        "cleaned_column_name": "account_id",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.966,
                        "original_sql_column_name": "account_id",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.account_id",
                    },
                    {
                        "n_unique": 10,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "basic|business|corporate|current|joint|online|personal|retirement|savings|student",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Payment Performance, Acounts Receivable Aging Report, Average Billing Amount per Customer",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Account Type",
                        "cleaned_column_name": "account_type",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Has_Current_Account_Flag",
                        "n_unique_per_row_count": 0.01,
                        "original_sql_column_name": "account_type",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.account_type",
                    },
                    {
                        "n_unique": 984,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "‘Aqrah|Afareaitu|Aghada|Agía Varvára|Ágios Spyrídon|Água Retorta|Aimorés|Aix-en-Provence|Aiximan|Akureyri",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Branch Name",
                        "cleaned_column_name": "branch_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.984,
                        "original_sql_column_name": "branch_name",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.branch_name",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "00-1662667|00-3418626|00-4722195|00-5362154|00-5585088|00-5655982|00-6292647|00-6881844|00-7943937|00-7997137",
                        "data_tribe": "id",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Customer ID",
                        "cleaned_column_name": "customer_ID",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "customer_ID",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.customer_ID",
                    },
                    {
                        "n_unique": 950,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Aaren|Abby|Abe|Ada|Adelaida|Adelind|Adlai|Adolf|Adrea|Adriaens",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "First Name",
                        "cleaned_column_name": "first_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.95,
                        "original_sql_column_name": "first_name",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.first_name",
                    },
                    {
                        "n_unique": 986,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Abbati|Abrahamsson|Abrams|Ackenhead|Adame|Adamiak|Adamsen|Adriaens|Aim|Aitchison",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Last Name",
                        "cleaned_column_name": "last_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.986,
                        "original_sql_column_name": "last_name",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.last_name",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "$10114.83|$10386.81|$10522.75|$10574.60|$10767.90|$10774.89|$10821.90|$10828.69|$10949.39|$11266.24",
                        "data_tribe": "numerical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Payment Performance, Acounts Receivable Aging Report, Average Billing Amount per Customer",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Transaction Amount",
                        "cleaned_column_name": "transaction_amount",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Transaction_Channel",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "transaction_amount",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.transaction_amount",
                    },
                    {
                        "n_unique": 596,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "01/01/2023|01/01/2024|01/02/2023|01/02/2024|01/03/2022|01/03/2023|01/03/2024|01/04/2022|01/05/2024|01/06/2022",
                        "data_tribe": "date_related",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Transaction Date",
                        "cleaned_column_name": "transaction_date",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Industry",
                        "n_unique_per_row_count": 0.596,
                        "original_sql_column_name": "transaction_date",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.transaction_date",
                    },
                    {
                        "n_unique": 22,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Automotive|Baby|Beauty|Books|Clothing|Computers|Electronics|Games|Garden|Grocery",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Payment Performance, Acounts Receivable Aging Report, Average Billing Amount per Customer",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Transaction Description",
                        "cleaned_column_name": "transaction_description",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Transaction_Channel",
                        "n_unique_per_row_count": 0.022,
                        "original_sql_column_name": "transaction_description",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.transaction_description",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "AD29 6650 2328 YTPS WRLO VLQN|AD54 6453 8754 6ZFA YXOP TMAW|AD62 7546 5974 YN6G AFJ0 IK6J|AD69 0563 0984 AV0T FRBA WWMR|AD71 8115 8430 7ZMA OLJQ J3RT|AD77 9386 3661 CASI JVIN WP0M|AD82 8103 2448 WFUE XCSW ZAEJ|AD85 6098 7347 IMRF P4LS 5IAC|AD96 7383 4000 AXLH ICZR 84FD|AE11 7305 4601 5159 2238 126",
                        "data_tribe": "id",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "",
                        "column_description": "Transaction ID",
                        "cleaned_column_name": "transaction_id",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Transactions_Type",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "transaction_id",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.transaction_id",
                    },
                    {
                        "n_unique": 10,
                        "sql_path": "blueriver_rdbms.trx_07_data",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "deposit|donation|exchange|fee|loan|purchase|refund|subscription|transfer|withdrawal",
                        "data_tribe": "categorical",
                        "table_name": "trx_07_data",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Transaction Type, a categorical value that describes the type of financial transaction, such as deposit, donation, exchange, fee, loan, purchase, refund, subscription, transfer, or withdrawal.",
                        "column_description": "Transaction Type",
                        "cleaned_column_name": "transaction_type",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Transactions_Type",
                        "n_unique_per_row_count": 0.01,
                        "original_sql_column_name": "transaction_type",
                        "sql_path_original_column_name": "blueriver_rdbms.trx_07_data.transaction_type",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "AD05 9959 2223 FWEC XJR4 QKGI|AD14 4707 7001 1ZVZ IRSY XPDN|AD17 3872 7448 BGSG 6ADT OGAB|AD25 0190 8133 63HC LHXW XWXQ|AD27 3598 0778 8JBK V9VC ZLNK|AD31 6483 0114 YD6U OTM5 N5NG|AD35 0143 4996 VN73 CD6K QIHV|AD55 6367 6729 ORHL Z2IE VFUI|AD70 2464 9693 2AU1 APBU WVCS|AD74 9377 4714 0QN9 LIXG UYWJ",
                        "data_tribe": "id",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Payment Performance, Acounts Receivable Aging Report, Average Billing Amount per Customer",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Bank Account ID is a unique identifier for a customer's bank account, consisting of a combination of letters and numbers, which is used to facilitate financial transactions.",
                        "column_description": "Bank Account ID",
                        "cleaned_column_name": "bank_account_id",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Has_Current_Account_Flag",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "bank_account_id",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.bank_account_id",
                    },
                    {
                        "n_unique": 362,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Abata|Agimba|Aibox|Ailane|Aimbo|Aimbu|Ainyx|Aivee|Avamba|Avamm",
                        "data_tribe": "categorical",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Company Name refers to the name of the company where the customer is employed, providing context for the customer's job title and role.",
                        "column_description": "Company Name",
                        "cleaned_column_name": "company_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "Industry",
                        "n_unique_per_row_count": 0.362,
                        "original_sql_column_name": "company_name",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.company_name",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "00-1033717|00-1499639|00-1537576|00-2364491|00-2435085|00-2602569|00-3463157|00-6079924|00-6843781|00-6930131",
                        "data_tribe": "id",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Customer ID is a unique identifier assigned to each customer, allowing for easy tracking and management of customer information and transactions.",
                        "column_description": "Customer ID",
                        "cleaned_column_name": "customer_ID",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "customer_ID",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.customer_ID",
                    },
                    {
                        "n_unique": 1000,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "aaxcell8q@dagondesign.com|abaldingq@jalbum.net|abanbrookgz@a8.net|abantingh2@desdev.cn|abishopppg@boston.com|aboakesoj@rakuten.co.jp|abroseman9h@google.pl|abubbinsqs@twitpic.com|acamelian9@umich.edu|acaserls@sohu.com",
                        "data_tribe": "textual",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Email is the electronic mail address of the customer, used for communication and electronic transactions.",
                        "column_description": "Email",
                        "cleaned_column_name": "email",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 1,
                        "original_sql_column_name": "email",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.email",
                    },
                    {
                        "n_unique": 946,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Aarika|Ab|Abdel|Abigale|Abram|Adah|Adelice|Adriaens|Adrianne|Adriano",
                        "data_tribe": "categorical",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "First Name is the given name of the customer, representing the initial part of their personal identity.",
                        "column_description": "First Name",
                        "cleaned_column_name": "first_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.946,
                        "original_sql_column_name": "first_name",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.first_name",
                    },
                    {
                        "n_unique": 8,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Agender|Bigender|Female|Genderfluid|Genderqueer|Male|Non-binary|Polygender",
                        "data_tribe": "categorical",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Gender is the self-identified gender of the customer, which can include various categories such as Female, Male, Agender, Bigender, Genderfluid, Genderqueer, Non-binary, Polygender, etc.",
                        "column_description": "Gender",
                        "cleaned_column_name": "gender",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.008,
                        "original_sql_column_name": "gender",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.gender",
                    },
                    {
                        "n_unique": 180,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Account Coordinator|Account Executive|Account Representative I|Account Representative II|Account Representative III|Account Representative IV|Accountant I|Accountant III|Accountant IV|Accounting Assistant I",
                        "data_tribe": "categorical",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Job Title is the official title of the customer's position within their company, reflecting their role and responsibilities.",
                        "column_description": "Job Title",
                        "cleaned_column_name": "job_title",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.18,
                        "original_sql_column_name": "job_title",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.job_title",
                    },
                    {
                        "n_unique": 989,
                        "sql_path": "blueriver_rdbms.customer_05_2024",
                        "avg_value": "None",
                        "max_value": "None",
                        "min_value": "None",
                        "row_count": 1000,
                        "std_value": "None",
                        "10_samples": "Abelov|Abelovitz|Abethell|Achromov|Adnams|Adolfsen|Adshede|Advani|Akester|Albany",
                        "data_tribe": "categorical",
                        "table_name": "customer_05_2024",
                        "kpi_def_from": "Customer Segmentation (Career)",
                        "database_name": "blueriver_rdbms",
                        "sql_data_type": "text",
                        "sql_tool_name": "MySQL",
                        "pct_null_values": 0,
                        "possible_values": "None",
                        "long_description": "Last Name is the family name or surname of the customer, representing the final part of their personal identity.",
                        "column_description": "Last Name",
                        "cleaned_column_name": "last_name",
                        "data_dictionary_flag": "None",
                        "final_kpi_column_match": "customer_ID",
                        "n_unique_per_row_count": 0.989,
                        "original_sql_column_name": "last_name",
                        "sql_path_original_column_name": "blueriver_rdbms.customer_05_2024.last_name",
                    },
                ],
                "Combined_LLM_Description": "This table is a comprehensive data asset, merging transaction data from 'trx_07_data' with customer information from 'customer_05_2024'. It facilitates in-depth transactional and customer analysis, supporting strategic decision-making and enhancing financial, marketing, and sales performance insights.",
            }
        ],
        "starhub_001",
        "goldius.leo@userdata.tech",
        "I'd be happy to assist you with customer transaction analysis. To provide a comprehensive analysis, I'll need to join the necessary tables. Please note that this may take some time.\n\nOnce completed, I will generate relevant charts and insights to help you better understand your customers' transaction patterns. You can expect to see information on:\n\n* Customer demographics\n* Transaction frequency and value\n* Product popularity and trends\n* Geographic distribution of customers\n\nPlease stand by while I work on generating the analysis. I'll",
    ],
    stream=False,
    headers={"Content-Type": "application/json", "accept": "application/json"},
    verify=False,
)

# for chunk in response.iter_content(100000000):
#     print(ast.literal_eval(chunk.decode("utf-8")))

print(f"respone code: {response.status_code}")
display(ast.literal_eval(response.content.decode("utf-8")))

# %% [markdown]
# # MySQL Competitive Graph Ups Summary (Unused)

# %%
import requests
import ast

response = requests.post(
    "http://0.0.0.0:8000/CAGraphUpsSummary",
    json=[
        "datalake.dummy_test",
        "Compare the revenue with Singtel",
        "Singtel",
        "all",
        "starhub_002",
        "EXT_MAG_sabilah.margirizki@userdata.tech",
    ],
)

print(f"respone code: {response.status_code}")
display(ast.literal_eval(response.content.decode("utf-8")))

# %% [markdown]
# # Update Chart Data

# %%
import requests

url = "http://localhost:8000/UpdateUps"

payload = [
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 1",
        "Visual_Title": "Monthly Revenue Trend for the Broadband Product (Past Year)",
        "Chart_Axis": {
            "xAxis_title": "Month",
            "xAxis_column": "Date",
            "yAxis_title": "Total Revenue",
            "yAxis_column": "Revenue",
            "yAxis_aggregation": "SUM",
            "yAxis2_title": "",
            "yAxis2_column": "",
            "yAxis2_aggregation": "",
            "yAxis3_title": "",
            "yAxis3_column": "",
            "yAxis3_aggregation": "",
            "series_title": "",
            "series_column": "",
        },
        "Chart_Query": "SELECT CONCAT(YEAR(STR_TO_DATE(Date, '%d/%m/%Y')), '-M', MONTH(STR_TO_DATE(Date, '%d/%m/%Y'))) AS xAxis, SUM(Revenue) AS yAxis FROM starhub_data_asset.data_asset_001_ta WHERE Product = 'Broadband' AND STR_TO_DATE(Date, '%d/%m/%Y') >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR) GROUP BY xAxis ORDER BY xAxis",
        "Chart_SQL_Library": "MariaDB",
        "Chart_Position": "1",
        "Chart_Type": "line_chart",
        "Chart_Title": "Monthly Revenue Trend for the Broadband Product (Past Year)",
        "xAxis": "Month",
        "xAxis_Description": "Month",
        "X": ["2023-M10", "2023-M11", "2023-M12"],
        "yAxis": "Total Revenue",
        "yAxis_Description": "Total Revenue",
        "Y": [2743715.0, 3278994.0, 3918701.0],
        "yName": "Total Revenue",
        "Aggregated_Table_JSON": {
            "Subscription_ID": "",
            "Subscription_Name": "",
            "Client_ID": "djofvojidfjoi",
            "User_ID": "jdfovdfjoivjidfo",
            "Shared_User_ID": "",
            "Chart_Name": "Visual 1",
            "Chart_Axis": {},
            "Chart_Query": "SELECT CONCAT(YEAR(STR_TO_DATE(Date, '%d/%m/%Y')), '-M', MONTH(STR_TO_DATE(Date, '%d/%m/%Y'))) AS xAxis, SUM(Revenue) AS yAxis FROM starhub_data_asset.data_asset_001_ta WHERE Product = 'Broadband' AND STR_TO_DATE(Date, '%d/%m/%Y') >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR) GROUP BY xAxis ORDER BY xAxis",
            "Chart_SQL_Library": "MariaDB",
            "Chart_Position": "1",
            "Chart_Type": "aggregated_table_chart",
            "Chart_Size": 88,
            "data": [
                {"Month": "2023-M10", "Total Revenue": 2743715.0},
                {"Month": "2023-M11", "Total Revenue": 3278994.0},
                {"Month": "2023-M12", "Total Revenue": 3918701.0},
            ],
            "Database_Identifier": "label3",
        },
        "Aggregated_Table_Column": ["Revenue", "Date"],
        "Database_Identifier": "label3",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 1",
        "Chart_Type": "text_content",
        "Chart_Position": "2",
        "Chart_Title": "Visual Description",
        "Card_Content": "\u2022 **Revenue Growth**: The total revenue shows a consistent upward trend over the three months (October to December 2023), indicating a positive growth pattern.\n\n\u2022 **Month-on-Month Increase**: The revenue increases by 19.5% from October to November (from $2,743,715 to $3,278,994) and by 19.4% from November to December (from $3,278,994 to $3,918,701), highlighting a steady month-on-month growth.\n\n\u2022 **Highest Revenue**: December 2023 records the highest total revenue at $3,918,701, making it the peak month among the three.\n\n\u2022 **Revenue Range**: The total revenue ranges from $2,743,715 (October 2023) to $3,918,701 (December 2023), indicating a significant variation in revenue across the months.\n\n\u2022 **Average Monthly Revenue**: The average monthly revenue for the three months is approximately $3,131,470, providing a baseline for future revenue projections.",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 1",
        "Chart_Type": "text_content",
        "Chart_Position": "3",
        "Chart_Title": "Business Recommendation",
        "Card_Content": "The monthly revenue trend for the broadband product exhibits an overall increasing trend, with a notable peak towards the end of the year. This upward trajectory may be attributed to various factors such as effective marketing campaigns, seasonal demand, or improved customer retention strategies. Understanding these trends can inform business decisions, such as optimizing resource allocation, refining marketing efforts, and setting realistic revenue targets, ultimately driving growth and competitiveness in the market.",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 2",
        "Visual_Title": "Monthly Cost Trend for the Broadband Product (Past Year)",
        "Chart_Axis": {
            "xAxis_title": "Month",
            "xAxis_column": "Date",
            "yAxis_title": "Total Cost",
            "yAxis_column": "Cost",
            "yAxis_aggregation": "SUM",
            "yAxis2_title": "",
            "yAxis2_column": "",
            "yAxis2_aggregation": "",
            "yAxis3_title": "",
            "yAxis3_column": "",
            "yAxis3_aggregation": "",
            "series_title": "",
            "series_column": "",
        },
        "Chart_Query": "SELECT CONCAT(YEAR(STR_TO_DATE(Date, '%d/%m/%Y')), '-M', MONTH(STR_TO_DATE(Date, '%d/%m/%Y'))) AS xAxis, SUM(Cost) AS yAxis FROM starhub_data_asset.data_asset_001_ta WHERE Product = 'Broadband' AND STR_TO_DATE(Date, '%d/%m/%Y') >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR) GROUP BY xAxis ORDER BY xAxis",
        "Chart_SQL_Library": "MariaDB",
        "Chart_Position": "1",
        "Chart_Type": "line_chart",
        "Chart_Title": "Monthly Cost Trend for the Broadband Product (Past Year)",
        "xAxis": "Month",
        "xAxis_Description": "Month",
        "X": ["2023-M10", "2023-M11", "2023-M12"],
        "yAxis": "Total Cost",
        "yAxis_Description": "Total Cost",
        "Y": [270249.0, 295567.0, 323257.0],
        "yName": "Total Cost",
        "Aggregated_Table_JSON": {
            "Subscription_ID": "",
            "Subscription_Name": "",
            "Client_ID": "djofvojidfjoi",
            "User_ID": "jdfovdfjoivjidfo",
            "Shared_User_ID": "",
            "Chart_Name": "Visual 2",
            "Chart_Axis": {},
            "Chart_Query": "SELECT CONCAT(YEAR(STR_TO_DATE(Date, '%d/%m/%Y')), '-M', MONTH(STR_TO_DATE(Date, '%d/%m/%Y'))) AS xAxis, SUM(Cost) AS yAxis FROM starhub_data_asset.data_asset_001_ta WHERE Product = 'Broadband' AND STR_TO_DATE(Date, '%d/%m/%Y') >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR) GROUP BY xAxis ORDER BY xAxis",
            "Chart_SQL_Library": "MariaDB",
            "Chart_Position": "1",
            "Chart_Type": "aggregated_table_chart",
            "Chart_Size": 88,
            "data": [
                {"Month": "2023-M10", "Total Cost": 270249.0},
                {"Month": "2023-M11", "Total Cost": 295567.0},
                {"Month": "2023-M12", "Total Cost": 323257.0},
            ],
            "Database_Identifier": "label3",
        },
        "Aggregated_Table_Column": ["Cost", "Date"],
        "Database_Identifier": "label3",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 2",
        "Chart_Type": "text_content",
        "Chart_Position": "2",
        "Chart_Title": "Visual Description",
        "Card_Content": "\u2022 **Increasing Trend**: The total cost shows an increasing trend over the past three months, from October 2023 to December 2023, with a steady rise in costs.\n\u2022 **Month-wise Breakdown**: The total cost for each month is: October 2023 ($270,249), November 2023 ($295,567), and December 2023 ($323,257).\n\u2022 **Highest Cost**: The highest total cost is recorded in December 2023, with a value of $323,257.\n\u2022 **Cost Increment**: The total cost increased by $25,318 from October 2023 to November 2023 and by $27,690 from November 2023 to December 2023.\n\u2022 **Total Cost Range**: The total cost range over the three months is between $270,249 (October 2023) and $323,257 (December 2023), indicating a significant increase in costs.",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 2",
        "Chart_Type": "text_content",
        "Chart_Position": "3",
        "Chart_Title": "Business Recommendation",
        "Card_Content": "The monthly cost trend for the broadband product exhibits an overall increasing trend, with a notable peak towards the end of the period. This upward trend could be attributed to various factors such as increased demand, seasonal fluctuations, or changes in pricing strategies. Understanding this trend can inform business decisions on resource allocation, pricing adjustments, and investment strategies to optimize costs and maintain competitiveness.",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 3",
        "Visual_Title": "Quarterly EBIT Trend for the Broadband Product (Past Year)",
        "Chart_Axis": {
            "xAxis_title": "Quarter",
            "xAxis_column": "Date",
            "yAxis_title": "Total EBIT",
            "yAxis_column": "EBIT",
            "yAxis_aggregation": "SUM",
            "yAxis2_title": "",
            "yAxis2_column": "",
            "yAxis2_aggregation": "",
            "yAxis3_title": "",
            "yAxis3_column": "",
            "yAxis3_aggregation": "",
            "series_title": "",
            "series_column": "",
        },
        "Chart_Query": "SELECT CONCAT(YEAR(STR_TO_DATE(Date, '%d/%m/%Y')), '-Q', QUARTER(STR_TO_DATE(Date, '%d/%m/%Y'))) AS xAxis, SUM(EBIT) AS yAxis FROM starhub_data_asset.data_asset_001_ta WHERE Product = 'Broadband' AND STR_TO_DATE(Date, '%d/%m/%Y') >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR) GROUP BY xAxis ORDER BY xAxis;",
        "Chart_SQL_Library": "MariaDB",
        "Chart_Position": "1",
        "Chart_Type": "card_chart",
        "Chart_Title": "Quarterly EBIT Trend for the Broadband Product (Past Year)",
        "yAxis": "Total Quarterly EBIT Trend for the Broadband Product (Past Year)",
        "yAxis_Description": "Total Quarterly EBIT Trend for the Broadband Product (Past Year)",
        "Y": "6,364.00\n(2023-Q4)",
        "Database_Identifier": "label3",
        "Original_Chart_Type": "bar_chart",
        "Aggregated_Table_Column": ["EBIT", "Date"],
        "Aggregated_Table_JSON": {
            "Subscription_ID": "",
            "Subscription_Name": "",
            "Client_ID": "djofvojidfjoi",
            "User_ID": "jdfovdfjoivjidfo",
            "Shared_User_ID": "",
            "Chart_Name": "Visual 3",
            "Chart_Axis": {},
            "Chart_Query": "SELECT CONCAT(YEAR(STR_TO_DATE(Date, '%d/%m/%Y')), '-Q', QUARTER(STR_TO_DATE(Date, '%d/%m/%Y'))) AS xAxis, SUM(EBIT) AS yAxis FROM starhub_data_asset.data_asset_001_ta WHERE Product = 'Broadband' AND STR_TO_DATE(Date, '%d/%m/%Y') >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR) GROUP BY xAxis ORDER BY xAxis;",
            "Chart_SQL_Library": "MariaDB",
            "Chart_Position": "1",
            "Chart_Type": "aggregated_table_chart",
            "Chart_Size": 88,
            "data": [{"Quarter": "2023-Q4", "Total EBIT": 6364.0}],
            "Database_Identifier": "label3",
        },
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 3",
        "Chart_Type": "text_content",
        "Chart_Position": "2",
        "Chart_Title": "Visual Description",
        "Card_Content": "\u2022 **Trend**: Total Quarterly EBIT shows a general upward trend over the past year, with the highest value in 2023-Q4.\n\u2022 **Key Value**: The highest Total Quarterly EBIT is $6,364.00, achieved in 2023-Q4.\n\u2022 **Pattern**: The data suggests a quarterly pattern, with EBIT values varying across each quarter.\n\u2022 **X-Axis Focus**: The x-axis (Quarter) highlights the time period, with data points likely representing consecutive quarters.\n\u2022 **Y-Axis Focus**: The y-axis (Total EBIT) measures the financial performance, with the highest value ($6,364.00) indicating peak performance in 2023-Q4.",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 3",
        "Chart_Type": "text_content",
        "Chart_Position": "3",
        "Chart_Title": "Business Recommendation",
        "Card_Content": "The quarterly EBIT trend for the broadband product exhibits a notable pattern, with a recent peak indicating a significant increase in earnings. This upward trend may be attributed to various factors, such as effective pricing strategies, improved operational efficiency, or increased demand for broadband services. Understanding this trend can inform business decisions, such as investing in infrastructure upgrades or exploring new market opportunities, to sustain and build upon this growth.",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 4",
        "Visual_Title": "Comparison of Monthly Revenue and Cost for the Broadband Product (Past Year)",
        "Chart_Axis": {
            "xAxis_title": "Month",
            "xAxis_column": "Date",
            "yAxisBar_title": "Total Revenue for Broadband",
            "yAxisBar_column": "Revenue",
            "yAxisBar_aggregation": "SUM",
            "yAxisLine_title": "Total Cost for Broadband",
            "yAxisLine_column": "Cost",
            "yAxisLine_aggregation": "SUM",
            "yAxis_title": "Total Revenue for Broadband",
            "yAxis_column": "Revenue",
            "yAxis_aggregation": "SUM",
            "yAxis2_title": "Total Cost for Broadband",
            "yAxis2_column": "Cost",
            "yAxis2_aggregation": "SUM",
            "series_title": "",
            "series_column": "",
        },
        "Chart_Query": "SELECT      CONCAT(YEAR(STR_TO_DATE(Date, '%d/%m/%Y')), '-M', MONTH(STR_TO_DATE(Date, '%d/%m/%Y'))) AS xAxis,      SUM(Revenue) AS yAxis,      SUM(Cost) AS yAxis2  FROM      starhub_data_asset.data_asset_001_ta  WHERE      Product = 'Broadband'      AND STR_TO_DATE(Date, '%d/%m/%Y') >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR)  GROUP BY      xAxis  ORDER BY      xAxis;",
        "Chart_SQL_Library": "MariaDB",
        "Chart_Position": "1",
        "Chart_Type": "grouped_bar_chart",
        "Chart_Title": "Comparison of Monthly Revenue and Cost for the Broadband Product (Past Year)",
        "xAxis": "Month",
        "xAxis_Description": "Month",
        "X": ["2023-M10", "2023-M11", "2023-M12"],
        "yAxis": "Amount",
        "yAxis_Description": "Amount",
        "Y": [2743715.0, 3278994.0, 3918701.0],
        "Y2": [270249.0, 295567.0, 323257.0],
        "yName": "Total Revenue for Broadband",
        "y2Name": "Total Cost for Broadband",
        "Aggregated_Table_JSON": {
            "Subscription_ID": "",
            "Subscription_Name": "",
            "Client_ID": "djofvojidfjoi",
            "User_ID": "jdfovdfjoivjidfo",
            "Shared_User_ID": "",
            "Chart_Name": "Visual 4",
            "Chart_Axis": {},
            "Chart_Query": "SELECT      CONCAT(YEAR(STR_TO_DATE(Date, '%d/%m/%Y')), '-M', MONTH(STR_TO_DATE(Date, '%d/%m/%Y'))) AS xAxis,      SUM(Revenue) AS yAxis,      SUM(Cost) AS yAxis2  FROM      starhub_data_asset.data_asset_001_ta  WHERE      Product = 'Broadband'      AND STR_TO_DATE(Date, '%d/%m/%Y') >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR)  GROUP BY      xAxis  ORDER BY      xAxis;",
            "Chart_SQL_Library": "MariaDB",
            "Chart_Position": "1",
            "Chart_Type": "aggregated_table_chart",
            "Chart_Size": 88,
            "data": [
                {
                    "Month": "2023-M10",
                    "Total Revenue for Broadband": 2743715.0,
                    "Total Cost for Broadband": 270249.0,
                },
                {
                    "Month": "2023-M11",
                    "Total Revenue for Broadband": 3278994.0,
                    "Total Cost for Broadband": 295567.0,
                },
                {
                    "Month": "2023-M12",
                    "Total Revenue for Broadband": 3918701.0,
                    "Total Cost for Broadband": 323257.0,
                },
            ],
            "Database_Identifier": "label3",
        },
        "Aggregated_Table_Column": ["Revenue", "Cost", "Date"],
        "Database_Identifier": "label3",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 4",
        "Chart_Type": "text_content",
        "Chart_Position": "2",
        "Chart_Title": "Visual Description",
        "Card_Content": "*   The total revenue for broadband increased by 42% from October 2023 to December 2023, with values ranging from 2,743,715 to 3,918,701 on the y-axis.\n*   The total cost for broadband increased by 19.5% from October 2023 to December 2023, with values ranging from 270,249 to 323,257 on the y-axis.\n*   The revenue growth rate outpaced the cost growth rate, indicating a potential increase in profitability.\n*   The highest total revenue for broadband was recorded in December 2023, with a value of 3,918,701 on the y-axis.\n*   The highest total cost for broadband was also recorded in December 2023, with a value of 323,257 on the y-axis.",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 4",
        "Chart_Type": "text_content",
        "Chart_Position": "3",
        "Chart_Title": "Business Recommendation",
        "Card_Content": "The trend in total revenue for broadband is increasing, while the total cost is also rising, albeit at a slower pace. The increase in revenue may be attributed to growing demand for broadband services, while the rising costs could be due to increased investments in network infrastructure or operational expenses. These insights can inform business decisions on pricing strategies, investment allocation, and resource optimization to maintain profitability and competitiveness in the market.",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 5",
        "Visual_Title": "Distribution of EBIT for the Broadband Product (Past Year)",
        "Chart_Axis": {"xAxis_title": "Year", "xAxis_column": "EBIT"},
        "Chart_Query": "SELECT CAST(EBIT AS CHAR) AS xAxis, COUNT(*) AS yAxis FROM starhub_data_asset.data_asset_001_ta WHERE Product = 'Broadband' AND STR_TO_DATE(Date, '%d/%m/%Y') >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR) GROUP BY xAxis ORDER BY xAxis",
        "Chart_SQL_Library": "MariaDB",
        "Chart_Position": "1",
        "Chart_Type": "histogram_chart",
        "Chart_Title": "Distribution of EBIT for the Broadband Product (Past Year)",
        "xAxis": "Year",
        "xAxis_Description": "Year",
        "X": ["0.5 - 0.7", "0.8 - 0.9", "1 - 1.1", "1.2 - 1.3", "1.4 - 1.5"],
        "yAxis": "Frequency",
        "yAxis_Description": "Frequency",
        "Y": [0, 0, 3, 0, 0],
        "Aggregated_Table_JSON": {
            "Subscription_ID": "",
            "Subscription_Name": "",
            "Client_ID": "djofvojidfjoi",
            "User_ID": "jdfovdfjoivjidfo",
            "Shared_User_ID": "",
            "Chart_Name": "Visual 5",
            "Chart_Axis": {},
            "Chart_Query": "SELECT CAST(EBIT AS CHAR) AS xAxis, COUNT(*) AS yAxis FROM starhub_data_asset.data_asset_001_ta WHERE Product = 'Broadband' AND STR_TO_DATE(Date, '%d/%m/%Y') >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR) GROUP BY xAxis ORDER BY xAxis",
            "Chart_SQL_Library": "MariaDB",
            "Chart_Position": "1",
            "Chart_Type": "aggregated_table_chart",
            "Chart_Size": 120,
            "data": [
                {"Year": "0.5 - 0.7", "Frequency": 0},
                {"Year": "0.8 - 0.9", "Frequency": 0},
                {"Year": "1 - 1.1", "Frequency": 3},
                {"Year": "1.2 - 1.3", "Frequency": 0},
                {"Year": "1.4 - 1.5", "Frequency": 0},
            ],
            "Database_Identifier": "label3",
        },
        "Aggregated_Table_Column": ["EBIT"],
        "Database_Identifier": "label3",
        "yName": "Frequency of Year",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 5",
        "Chart_Type": "text_content",
        "Chart_Position": "2",
        "Chart_Title": "Visual Description",
        "Card_Content": "\u2022 The histogram chart represents the distribution of EBIT (Earnings Before Interest and Taxes) for the Broadband Product over the past year, with the x-axis showing EBIT ranges and the y-axis showing frequency.\n\n\u2022 The EBIT ranges are categorized into five bins: 0.5-0.7, 0.8-0.9, 1-1.1, 1.2-1.3, and 1.4-1.5, providing a clear visualization of the EBIT distribution.\n\n\u2022 The highest frequency (3) is observed in the EBIT range of 1-1.1, indicating that most of the data points fall within this range.\n\n\u2022 The EBIT ranges 0.5-0.7, 0.8-0.9, 1.2-1.3, and 1.4-1.5 have zero frequency, suggesting that there are no data points in these ranges.\n\n\u2022 The data suggests a relatively narrow distribution of EBIT, with most values concentrated in the 1-1.1 range, which could indicate a stable financial performance for the Broadband Product.",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 5",
        "Chart_Type": "text_content",
        "Chart_Position": "3",
        "Chart_Title": "Business Recommendation",
        "Card_Content": "The distribution of EBIT for the broadband product exhibits a trend with a distinct peak, indicating a concentrated period of high earnings. This peak may be attributed to various factors such as successful marketing campaigns, seasonal fluctuations, or changes in consumer behavior. Understanding the causes behind this trend can inform business decisions, such as optimizing marketing strategies or resource allocation, to capitalize on periods of high earnings and drive growth.",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "djofvojidfjoi",
        "User_ID": "jdfovdfjoivjidfo",
        "Shared_User_ID": "",
        "Chart_Name": "Table",
        "Visual_Title": "Data Asset Table",
        "Chart_Axis": {},
        "Chart_Query": "SELECT * FROM `starhub_data_asset`.`data_asset_001_ta`;",
        "Chart_SQL_Library": "MariaDB",
        "Chart_Position": "1",
        "Chart_Type": "full_table_chart",
        "Chart_Title": "Data Asset Table",
        "Chart_Size": 664,
        "data": [
            {
                "Product": "BroadBand",
                "Date": "01/09/2023",
                "Revenue": 2295818,
                "Cost": 247099,
                "EBIT": 2154,
            },
            {
                "Product": "BroadBand",
                "Date": "01/05/2023",
                "Revenue": 1125463,
                "Cost": 172704,
                "EBIT": 2135,
            },
            {
                "Product": "BroadBand",
                "Date": "01/07/2023",
                "Revenue": 1607439,
                "Cost": 206579,
                "EBIT": 2144,
            },
            {
                "Product": "BroadBand",
                "Date": "01/04/2023",
                "Revenue": 941737,
                "Cost": 157910,
                "EBIT": 2069,
            },
            {
                "Product": "BroadBand",
                "Date": "01/03/2023",
                "Revenue": 788004,
                "Cost": 144383,
                "EBIT": 2126,
            },
            {
                "Product": "BroadBand",
                "Date": "01/02/2023",
                "Revenue": 659366,
                "Cost": 132015,
                "EBIT": 2060,
            },
            {
                "Product": "BroadBand",
                "Date": "01/08/2023",
                "Revenue": 1921038,
                "Cost": 225933,
                "EBIT": 2087,
            },
            {
                "Product": "BroadBand",
                "Date": "01/01/2023",
                "Revenue": 551728,
                "Cost": 120707,
                "EBIT": 2117,
            },
            {
                "Product": "BroadBand",
                "Date": "01/12/2023",
                "Revenue": 3918701,
                "Cost": 323257,
                "EBIT": 2105,
            },
            {
                "Product": "BroadBand",
                "Date": "01/12/2022",
                "Revenue": 461661,
                "Cost": 110367,
                "EBIT": 2051,
            },
            {
                "Product": "BroadBand",
                "Date": "01/11/2022",
                "Revenue": 386298,
                "Cost": 100913,
                "EBIT": 2107,
            },
            {
                "Product": "BroadBand",
                "Date": "01/10/2022",
                "Revenue": 323237,
                "Cost": 92269,
                "EBIT": 2042,
            },
            {
                "Product": "BroadBand",
                "Date": "01/09/2022",
                "Revenue": 270470,
                "Cost": 84365,
                "EBIT": 2098,
            },
            {
                "Product": "BroadBand",
                "Date": "01/08/2022",
                "Revenue": 226317,
                "Cost": 77138,
                "EBIT": 2033,
            },
            {
                "Product": "BroadBand",
                "Date": "01/07/2022",
                "Revenue": 189372,
                "Cost": 70531,
                "EBIT": 2089,
            },
            {
                "Product": "BroadBand",
                "Date": "01/10/2023",
                "Revenue": 2743715,
                "Cost": 270249,
                "EBIT": 2096,
            },
            {
                "Product": "BroadBand",
                "Date": "01/06/2023",
                "Revenue": 1345033,
                "Cost": 188884,
                "EBIT": 2078,
            },
            {
                "Product": "BroadBand",
                "Date": "01/02/2022",
                "Revenue": 77680,
                "Cost": 45073,
                "EBIT": 2006,
            },
            {
                "Product": "BroadBand",
                "Date": "01/04/2022",
                "Revenue": 110946,
                "Cost": 53914,
                "EBIT": 2015,
            },
            {
                "Product": "BroadBand",
                "Date": "01/03/2022",
                "Revenue": 92835,
                "Cost": 49296,
                "EBIT": 2070,
            },
            {
                "Product": "BroadBand",
                "Date": "01/11/2023",
                "Revenue": 3278994,
                "Cost": 295567,
                "EBIT": 2163,
            },
            {
                "Product": "BroadBand",
                "Date": "01/05/2022",
                "Revenue": 132591,
                "Cost": 58965,
                "EBIT": 2080,
            },
            {
                "Product": "BroadBand",
                "Date": "01/06/2022",
                "Revenue": 158458,
                "Cost": 64489,
                "EBIT": 2024,
            },
            {
                "Product": "BroadBand",
                "Date": "01/01/2022",
                "Revenue": 64999,
                "Cost": 41212,
                "EBIT": 2061,
            },
            {
                "Product": "Entertainment",
                "Date": "01/02/2022",
                "Revenue": 73199,
                "Cost": 43747,
                "EBIT": 2064,
            },
            {
                "Product": "Entertainment",
                "Date": "01/04/2023",
                "Revenue": 887420,
                "Cost": 153266,
                "EBIT": 2129,
            },
            {
                "Product": "Entertainment",
                "Date": "01/05/2023",
                "Revenue": 1060549,
                "Cost": 167625,
                "EBIT": 2072,
            },
            {
                "Product": "Entertainment",
                "Date": "01/03/2023",
                "Revenue": 742553,
                "Cost": 140137,
                "EBIT": 2063,
            },
            {
                "Product": "Entertainment",
                "Date": "01/08/2023",
                "Revenue": 1810237,
                "Cost": 219288,
                "EBIT": 2148,
            },
            {
                "Product": "Entertainment",
                "Date": "01/02/2023",
                "Revenue": 621336,
                "Cost": 128133,
                "EBIT": 2120,
            },
            {
                "Product": "Entertainment",
                "Date": "01/03/2022",
                "Revenue": 87480,
                "Cost": 47846,
                "EBIT": 2009,
            },
            {
                "Product": "Entertainment",
                "Date": "01/07/2023",
                "Revenue": 1514725,
                "Cost": 200504,
                "EBIT": 2081,
            },
            {
                "Product": "Entertainment",
                "Date": "01/01/2023",
                "Revenue": 519906,
                "Cost": 117157,
                "EBIT": 2054,
            },
            {
                "Product": "Entertainment",
                "Date": "01/12/2023",
                "Revenue": 3692680,
                "Cost": 313750,
                "EBIT": 2166,
            },
            {
                "Product": "Entertainment",
                "Date": "01/06/2022",
                "Revenue": 149319,
                "Cost": 62592,
                "EBIT": 2083,
            },
            {
                "Product": "Entertainment",
                "Date": "01/04/2022",
                "Revenue": 104547,
                "Cost": 52328,
                "EBIT": 2073,
            },
            {
                "Product": "Entertainment",
                "Date": "01/01/2022",
                "Revenue": 61250,
                "Cost": 40000,
                "EBIT": 2000,
            },
            {
                "Product": "Entertainment",
                "Date": "01/11/2022",
                "Revenue": 364017,
                "Cost": 97945,
                "EBIT": 2045,
            },
            {
                "Product": "Entertainment",
                "Date": "01/09/2023",
                "Revenue": 2163401,
                "Cost": 239832,
                "EBIT": 2090,
            },
            {
                "Product": "Entertainment",
                "Date": "01/11/2023",
                "Revenue": 3089869,
                "Cost": 286875,
                "EBIT": 2099,
            },
            {
                "Product": "Entertainment",
                "Date": "01/07/2022",
                "Revenue": 178450,
                "Cost": 68456,
                "EBIT": 2027,
            },
            {
                "Product": "Entertainment",
                "Date": "01/10/2022",
                "Revenue": 304593,
                "Cost": 89555,
                "EBIT": 2101,
            },
            {
                "Product": "Entertainment",
                "Date": "01/06/2023",
                "Revenue": 1267454,
                "Cost": 183329,
                "EBIT": 2138,
            },
            {
                "Product": "Entertainment",
                "Date": "01/05/2022",
                "Revenue": 124943,
                "Cost": 57231,
                "EBIT": 2018,
            },
            {
                "Product": "Entertainment",
                "Date": "01/12/2022",
                "Revenue": 435034,
                "Cost": 107121,
                "EBIT": 2110,
            },
            {
                "Product": "Entertainment",
                "Date": "01/09/2022",
                "Revenue": 254870,
                "Cost": 81884,
                "EBIT": 2036,
            },
            {
                "Product": "Entertainment",
                "Date": "01/08/2022",
                "Revenue": 213264,
                "Cost": 74870,
                "EBIT": 2092,
            },
            {
                "Product": "Entertainment",
                "Date": "01/10/2023",
                "Revenue": 2585464,
                "Cost": 262301,
                "EBIT": 2157,
            },
            {
                "Product": "Mobile",
                "Date": "01/10/2023",
                "Revenue": 2911653,
                "Cost": 278438,
                "EBIT": 2160,
            },
            {
                "Product": "Mobile",
                "Date": "01/08/2023",
                "Revenue": 2038621,
                "Cost": 232779,
                "EBIT": 2151,
            },
            {
                "Product": "Mobile",
                "Date": "01/11/2023",
                "Revenue": 3479695,
                "Cost": 304523,
                "EBIT": 2102,
            },
            {
                "Product": "Mobile",
                "Date": "01/09/2023",
                "Revenue": 2436341,
                "Cost": 254587,
                "EBIT": 2093,
            },
            {
                "Product": "Mobile",
                "Date": "01/07/2023",
                "Revenue": 1705827,
                "Cost": 212839,
                "EBIT": 2084,
            },
            {
                "Product": "Mobile",
                "Date": "01/12/2022",
                "Revenue": 489919,
                "Cost": 113711,
                "EBIT": 2114,
            },
            {
                "Product": "Mobile",
                "Date": "01/05/2023",
                "Revenue": 1194351,
                "Cost": 177937,
                "EBIT": 2075,
            },
            {
                "Product": "Mobile",
                "Date": "01/01/2022",
                "Revenue": 68977,
                "Cost": 42461,
                "EBIT": 2003,
            },
            {
                "Product": "Mobile",
                "Date": "01/02/2022",
                "Revenue": 82434,
                "Cost": 46439,
                "EBIT": 2067,
            },
            {
                "Product": "Mobile",
                "Date": "01/03/2022",
                "Revenue": 98517,
                "Cost": 50789,
                "EBIT": 2012,
            },
            {
                "Product": "Mobile",
                "Date": "01/04/2022",
                "Revenue": 117737,
                "Cost": 55548,
                "EBIT": 2076,
            },
            {
                "Product": "Mobile",
                "Date": "01/05/2022",
                "Revenue": 140706,
                "Cost": 60752,
                "EBIT": 2021,
            },
            {
                "Product": "Mobile",
                "Date": "01/06/2022",
                "Revenue": 168157,
                "Cost": 66443,
                "EBIT": 2086,
            },
            {
                "Product": "Mobile",
                "Date": "01/07/2022",
                "Revenue": 200963,
                "Cost": 72668,
                "EBIT": 2030,
            },
            {
                "Product": "Mobile",
                "Date": "01/08/2022",
                "Revenue": 240170,
                "Cost": 79476,
                "EBIT": 2095,
            },
            {
                "Product": "Mobile",
                "Date": "01/09/2022",
                "Revenue": 287025,
                "Cost": 86921,
                "EBIT": 2039,
            },
            {
                "Product": "Mobile",
                "Date": "01/10/2022",
                "Revenue": 343021,
                "Cost": 95065,
                "EBIT": 2104,
            },
            {
                "Product": "Mobile",
                "Date": "01/11/2022",
                "Revenue": 409942,
                "Cost": 103971,
                "EBIT": 2048,
            },
            {
                "Product": "Mobile",
                "Date": "01/01/2023",
                "Revenue": 585498,
                "Cost": 124365,
                "EBIT": 2057,
            },
            {
                "Product": "Mobile",
                "Date": "01/02/2023",
                "Revenue": 699725,
                "Cost": 136016,
                "EBIT": 2123,
            },
            {
                "Product": "Mobile",
                "Date": "01/03/2023",
                "Revenue": 836236,
                "Cost": 148758,
                "EBIT": 2066,
            },
            {
                "Product": "Mobile",
                "Date": "01/04/2023",
                "Revenue": 999379,
                "Cost": 162695,
                "EBIT": 2132,
            },
            {
                "Product": "Mobile",
                "Date": "01/06/2023",
                "Revenue": 1427360,
                "Cost": 194607,
                "EBIT": 2141,
            },
            {
                "Product": "Mobile",
                "Date": "01/12/2023",
                "Revenue": 4158557,
                "Cost": 333052,
                "EBIT": 2169,
            },
        ],
        "Database_Identifier": "label3",
    },
]

headers = {"Content-Type": "application/json", "accept": "application/json"}

response = requests.request("POST", url, headers=headers, json=payload)

print(f"respone code: {response.status_code}")
display(response.json())

# %%
import requests

url = "http://localhost:8000/UpdateUps"

payload = [
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "starhub_001",
        "User_ID": "goldius.leo@userdata.tech",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 1",
        "Chart_Axis": {
            "xAxis_title": "Income Level",
            "xAxis_column": "income_level",
            "yAxis_title": "Number of Customers",
            "yAxis_column": "cid",
            "yAxis_aggregation": "SUM",
            "yAxis2_title": "",
            "yAxis2_column": "",
            "yAxis2_aggregation": "",
            "yAxis3_title": "",
            "yAxis3_column": "",
            "yAxis3_aggregation": "",
            "series_title": "",
            "series_column": "",
        },
        "Chart_Query": "SELECT income_level AS xAxis, COUNT(cid) AS yAxis FROM ada_banks_data_asset.report_cross_selling_performance_product_type GROUP BY income_level ORDER BY xAxis;",
        "Chart_SQL_Library": "MySQL",
        "Chart_Position": "1",
        "Chart_Type": "grouped_bar_chart",
        "Chart_Title": "Distribution of Customers by Income Level",
        "xAxis": "Income Level",
        "yAxis": "Total Number of Customers",
        "Chart_Data": [[]],
        "Aggregated_Table_JSON": {
            "Subscription_ID": "",
            "Subscription_Name": "",
            "Client_ID": "starhub_001",
            "User_ID": "goldius.leo@userdata.tech",
            "Shared_User_ID": "",
            "Chart_Name": "Visual 1",
            "Chart_Axis": {},
            "Chart_Query": "SELECT income_level AS xAxis, COUNT(cid) AS yAxis FROM ada_banks_data_asset.report_cross_selling_performance_product_type GROUP BY income_level ORDER BY xAxis;",
            "Chart_SQL_Library": "MySQL",
            "Chart_Position": "1",
            "Chart_Type": "aggregated_table_chart",
            "Chart_Size": 120,
            "data": [],
            "Database_Identifier": "label1",
        },
        "Aggregated_Table_Column": ["income_level", "cid"],
        "Database_Identifier": "label1",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "starhub_001",
        "User_ID": "goldius.leo@userdata.tech",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 1",
        "Chart_Type": "text_content",
        "Chart_Position": "2",
        "Chart_Title": "Visual Description",
        "Card_Content": "",
    },
    {
        "Subscription_ID": "",
        "Subscription_Name": "",
        "Client_ID": "starhub_001",
        "User_ID": "goldius.leo@userdata.tech",
        "Shared_User_ID": "",
        "Chart_Name": "Visual 1",
        "Chart_Type": "text_content",
        "Chart_Position": "3",
        "Chart_Title": "Business Recommendation",
        "Card_Content": "",
    },
]

headers = {"Content-Type": "application/json", "accept": "application/json"}

response = requests.request("POST", url, headers=headers, json=payload)

print(f"respone code: {response.status_code}")
display(response.json())
